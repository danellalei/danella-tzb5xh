# %%
# !pip install --upgrade pymongo certifi
# Out:
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (2024.8.30)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 16.9 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 22.2 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %%
from pymongo import MongoClient
import pprint

connection_string = "mongodb+srv://uicerainbow:Sports628!@cluster0.dbd2a.mongodb.net/test?retryWrites=true&w=majority"
client = MongoClient(connection_string)

db = client['sample_mflix']
collection = db['movies']

# %%
action_movie = collection.find_one({'genres': 'Action'})
pprint.pprint(action_movie)
# Out:
# {'_id': ObjectId('573a1394f29313caabcde77d'),
#  'awards': {'nominations': 1,
#             'text': 'Won 2 Oscars. Another 2 wins & 1 nomination.',
#             'wins': 4},
#  'cast': ['Deborah Kerr', 'Stewart Granger', 'Richard Carlson', 'Hugo Haas'],
#  'countries': ['USA'],
#  'directors': ['Compton Bennett', 'Andrew Marton'],
#  'fullplot': 'Guide Allan Quatermain helps a young lady (Beth) find her lost '
#              "husband somewhere in Africa. It's a spectacular adventure story "
#              'with romance, because while they fight with wild animals and '
#              'cannibals, they fall in love. Will they find the lost husband '
#              'and finish the nice connection?',
#  'genres': ['Adventure', 'Romance', 'Action'],
#  'imdb': {'id': 42646, 'rating': 6.9, 'votes': 4128},
#  'languages': ['English'],
#  'lastupdated': '2015-08-06 00:32:20.070000000',
#  'num_mflix_comments': 1,
#  'plot': 'Adventurer Allan Quartermain leads an expedition into uncharted '
#          'African territory in an attempt to locate an explorer who went '
#          'missing during his search for the fabled diamond mines of King '
#          'Solomon.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjZlOWFjNzktMDQ3OC00ODQxLWEzZjMtN2E0Y2MwM2FkMzE0XkEyXkFqcGdeQXVyNTEwNDcxNDc@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1950, 11, 24, 0, 0),
#  'runtime': 103,
#  'title': "King Solomon's Mines",
#  'tomatoes': {'critic': {'meter': 92, 'numReviews': 12, 'rating': 7.2},
#               'dvd': datetime.datetime(2005, 1, 11, 0, 0),
#               'fresh': 11,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 19, 11, 25),
#               'production': 'MGM Home Entertainment',
#               'rotten': 1,
#               'viewer': {'meter': 60, 'numReviews': 3186, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['Helen Deutsch (screenplay)', 'H. Rider Haggard (novel)'],
#  'year': 1950}

# %% [markdown]
# 2. Write a query to find all movies released after the year 2000 (Return the first 5 Results)

# %%
movies_after_2000 = collection.find({'year': {'$gt': 2000}}).limit(5)

for movie in movies_after_2000.limit(5):
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1393f29313caabcdcb42'),
#  'awards': {'nominations': 4,
#             'text': 'Nominated for 1 Oscar. Another 1 win & 4 nominations.',
#             'wins': 2},
#  'cast': ['Meg Ryan', 'Hugh Jackman', 'Liev Schreiber', 'Breckin Meyer'],
#  'countries': ['USA'],
#  'directors': ['James Mangold'],
#  'fullplot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#              'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#              'space near the Brooklyn Bridge where there is a gap in time. He '
#              'goes back to the 19th Century and takes pictures of the place. '
#              "Leopold -- a man living in the 1870s -- is puzzled by Stuart's "
#              'tiny camera, follows him back through the gap, and they both '
#              'ended up in the present day. Leopold is clueless about his new '
#              'surroundings. He gets help and insight from Charlie who thinks '
#              'that Leopold is an actor who is always in character. Leopold is '
#              'a highly intelligent man and tries his best to learn and even '
#              'improve the modern conveniences that he encounters.',
#  'genres': ['Comedy', 'Fantasy', 'Romance'],
#  'imdb': {'id': 35423, 'rating': 6.3, 'votes': 59951},
#  'languages': ['English', 'French'],
#  'lastupdated': '2015-08-31 00:19:09.717000000',
#  'metacritic': 44,
#  'num_mflix_comments': 0,
#  'plot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#          'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#          'space near the Brooklyn Bridge where there is a gap in time....',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNmNlN2VlOTctYTdhMS00NzUxLTg0ZGMtYWE2ZTJmMThlMTk2XkEyXkFqcGdeQXVyMzI0NDc4ODY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2001, 12, 25, 0, 0),
#  'runtime': 118,
#  'title': 'Kate & Leopold',
#  'tomatoes': {'boxOffice': '$47.1M',
#               'consensus': 'Though Jackman charms, Kate and Leopold is bland '
#                            'and predictable, and the time travel scenario '
#                            'lacks inner logic.',
#               'critic': {'meter': 50, 'numReviews': 126, 'rating': 5.3},
#               'dvd': datetime.datetime(2002, 6, 11, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 8, 22, 18, 53, 25),
#               'production': 'Miramax Films',
#               'rotten': 63,
#               'viewer': {'meter': 62, 'numReviews': 189426, 'rating': 3.0},
#               'website': 'http://www.kateandleopold-themovie.com'},
#  'type': 'movie',
#  'writers': ['Steven Rogers (story)',
#              'James Mangold (screenplay)',
#              'Steven Rogers (screenplay)'],
#  'year': 2001}
# {'_id': ObjectId('573a1398f29313caabceb1fe'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Crispin Glover', 'Vanessa Redgrave', 'John Hurt', 'Margot Kidder'],
#  'countries': ['USA', 'Poland', 'Russia'],
#  'directors': ['Menahem Golan'],
#  'fullplot': "A modern day adaptation of Dostoyevsky's classic novel about a "
#              'young student who is forever haunted by the murder he has '
#              'committed.',
#  'genres': ['Drama'],
#  'imdb': {'id': 96056, 'rating': 6.4, 'votes': 463},
#  'languages': ['English', 'Polish'],
#  'lastupdated': '2015-08-13 00:34:02.303000000',
#  'num_mflix_comments': 0,
#  'plot': "A modern day adaptation of Dostoyevsky's classic novel about a young "
#          'student who is forever haunted by the murder he has committed.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTI3MDQ2MzEyOV5BMl5BanBnXkFtZTcwNzEwODUzMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2002, 6, 1, 0, 0),
#  'runtime': 126,
#  'title': 'Crime and Punishment',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 22, 18, 45, 10),
#               'viewer': {'numReviews': 0, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Fyodor Dostoevsky (novel)',
#              'Menahem Golan (adaptation)',
#              'Menahem Golan (screenplay)'],
#  'year': 2002}
# {'_id': ObjectId('573a139af29313caabcf0809'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Marcelo Games', 'Marc Pitman', 'Leslie Orr', 'Maureen Allisse'],
#  'countries': ['USA'],
#  'directors': ['Jim Van Bebber'],
#  'fullplot': 'If you think you know the story of the Manson Family, you are '
#              'dead wrong. On a ranch outside of Los Angeles, the dream of the '
#              '"Love Generation" is transforming into something evil. What was '
#              'once an oasis of free love and acid trips has become ground zero '
#              "for a madman's paranoid visions. An average group of kids, the "
#              '"Family," become engulfed in a delusional world where torment '
#              'and slaughter are considered the path to righteousness.Director '
#              'Jim VanBebber (Deadbeat at Dawn) delivers a dizzying, rapid-fire '
#              'vision of the sex and violence that unifies the misguided group, '
#              'a group hell-bent on executing the brutal vision of its leader, '
#              "Charles Manson. You've seen the story through the eyes of the "
#              'law. Now witness it through the eyes of THE MANSOSN FAMILY.',
#  'genres': ['Crime', 'Drama', 'History'],
#  'imdb': {'id': 118840, 'rating': 5.5, 'votes': 2565},
#  'languages': ['English'],
#  'lastupdated': '2015-09-03 00:41:23.867000000',
#  'metacritic': 56,
#  'num_mflix_comments': 0,
#  'plot': 'If you think you know the story of the Manson Family, you are dead '
#          'wrong. On a ranch outside of Los Angeles, the dream of the "Love '
#          'Generation" is transforming into something evil. What was...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTk1NDIzMjY3M15BMl5BanBnXkFtZTcwODE2ODYyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2004, 7, 23, 0, 0),
#  'runtime': 95,
#  'title': 'The Manson Family',
#  'tomatoes': {'critic': {'meter': 68, 'numReviews': 31, 'rating': 6.0},
#               'dvd': datetime.datetime(2005, 4, 26, 0, 0),
#               'fresh': 21,
#               'lastUpdated': datetime.datetime(2015, 7, 20, 18, 38, 35),
#               'production': 'Blue Underground',
#               'rotten': 10,
#               'viewer': {'meter': 48, 'numReviews': 7479, 'rating': 3.0},
#               'website': 'http://www2.themansonfamilymovie.com/'},
#  'type': 'movie',
#  'writers': ['Jim Van Bebber'],
#  'year': 2003}
# {'_id': ObjectId('573a139af29313caabcf0718'),
#  'awards': {'nominations': 8, 'text': '1 win & 8 nominations.', 'wins': 1},
#  'cast': ['Mariah Carey', 'Max Beesley', 'Da Brat', 'Tia Texada'],
#  'countries': ['USA'],
#  'directors': ['Vondie Curtis-Hall'],
#  'fullplot': 'Billie Frank is a shy, young multiracial girl who is sent away '
#              'by her alcoholic mother at a very early age. At an orphanage, '
#              'she befriends Louise and Roxanne. Flash forward to 1983. Billie '
#              'and her friends are spotted by a record producer, Timothy '
#              'Walker, who wants them to sing backup for his latest pop-music '
#              "discovery. But when super DJ Julian Dice hears Billie's "
#              'incredible voice, he makes a shady deal with Timothy to get her '
#              'out of that dead-end situation. Soon, Billie and Dice are making '
#              'hits inside the studio, and falling in love outside of it. '
#              'Eventually, the pressure of her newfound celebrity puts too '
#              'heavy a strain on Billie, forcing her to decide what it is she '
#              'really wants from Dice, and what she wants for herself.',
#  'genres': ['Drama', 'Music', 'Romance'],
#  'imdb': {'id': 118589, 'rating': 2.1, 'votes': 18840},
#  'languages': ['English'],
#  'lastupdated': '2015-08-21 00:47:31.610000000',
#  'metacritic': 14,
#  'num_mflix_comments': 0,
#  'plot': 'A young singer dates a disc jockey who helps her get into the music '
#          'business, but their relationship become complicated as she ascends '
#          'to super stardom.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMGJkN2IxNTYtZDE1OS00MWJhLWFhNzItNTZkMjM4OGUzMTE2L2ltYWdlXkEyXkFqcGdeQXVyNTg3MTc4ODY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2001, 9, 21, 0, 0),
#  'runtime': 104,
#  'title': 'Glitter',
#  'tomatoes': {'boxOffice': '$3.9M',
#               'consensus': 'Glitter is a hodgepodge of movie cliches and bad '
#                            "acting that's sure to generate unintentional "
#                            'laughs. Unfortunately, the movie is not bad enough '
#                            'to be good.',
#               'critic': {'meter': 7, 'numReviews': 87, 'rating': 2.8},
#               'dvd': datetime.datetime(2002, 1, 15, 0, 0),
#               'fresh': 6,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 18, 37, 3),
#               'production': '20th Century Fox',
#               'rotten': 81,
#               'viewer': {'meter': 45, 'numReviews': 44284, 'rating': 2.1},
#               'website': 'http://216.133.243.94'},
#  'type': 'movie',
#  'writers': ['Cheryl L. West (story)', 'Kate Lanier (screenplay)'],
#  'year': 2001}
# {'_id': ObjectId('573a139af29313caabcf0869'),
#  'awards': {'nominations': 3, 'text': '1 win & 3 nominations.', 'wins': 1},
#  'cast': ['Javier Bardem',
#           'Juan Diego Botto',
#           'Laura Morante',
#           'Elvira Mènguez'],
#  'countries': ['Spain', 'USA'],
#  'directors': ['John Malkovich'],
#  'fullplot': 'The story of Detective Agustin Rejas, a man clinging to the hope '
#              'of an impossible love in an impossible world. Tracking Ezequiel, '
#              'a delusional anarchist who incites the downtrodden masses to '
#              'join in his brutal revolution against the fascist government in '
#              'their unnamed Latin American country, Rejas finds solace in his '
#              'sense of self-respect and the joy that his daughter and wife '
#              "bring him. Then he meets Yolanda--his daughter's soulfully "
#              'beautiful ballet teacher--a woman who sparks his long-forgotten '
#              'passions and represents all that is good and all that is corrupt '
#              'in their troubled country. But she, who appears to be a shelter '
#              "from the storm, may in actuality be the storm's eye. Ultimately, "
#              'as the revolution intensifies and the net closes around hunter '
#              "and hunted alike, the dancer's truth will prove as elusive as "
#              "the revolutionary's cause and the detective's peace.",
#  'genres': ['Drama', 'Thriller', 'Crime'],
#  'imdb': {'id': 118926, 'rating': 7.0, 'votes': 5359},
#  'languages': ['English', 'Quechua', 'Spanish'],
#  'lastupdated': '2015-09-07 01:12:12.077000000',
#  'metacritic': 64,
#  'num_mflix_comments': 0,
#  'plot': 'A police detective in a South American country is dedicated to '
#          'hunting down a revolutionary guerilla leader.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BODE2ODA5OTE1OV5BMl5BanBnXkFtZTYwNzk1MTc2._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2003, 5, 23, 0, 0),
#  'runtime': 132,
#  'title': 'The Dancer Upstairs',
#  'tomatoes': {'boxOffice': '$2.3M',
#               'consensus': 'Javier Bardem is compelling in the lead role as a '
#                            'police detective in search of a violent, '
#                            'mysterious politcal radical, and as a director, '
#                            'John Malkovich proves adept at crafting a '
#                            'suspenseful mood.',
#               'critic': {'meter': 64, 'numReviews': 114, 'rating': 6.4},
#               'dvd': datetime.datetime(2003, 9, 23, 0, 0),
#               'fresh': 73,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 10, 37, 43),
#               'production': 'Fox Searchlight Pictures',
#               'rotten': 41,
#               'viewer': {'meter': 77, 'numReviews': 4793, 'rating': 3.6},
#               'website': 'http://www.foxsearchlight.com/thedancerupstairs/'},
#  'type': 'movie',
#  'writers': ['Nicholas Shakespeare (novel)',
#              'Nicholas Shakespeare (screenplay)'],
#  'year': 2002}

# %% [markdown]
# 3. Write a query to find all movies where the IMDb rating is greater than 8.5 (Return the first 5 results)

# %%
high_rated_movies = collection.find({'imdb.rating': {'$gt': 8.5}}).limit(5)

for movie in high_rated_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1394f29313caabcdfa00'),
#  'awards': {'nominations': 7,
#             'text': 'Nominated for 4 Oscars. Another 7 wins & 7 nominations.',
#             'wins': 11},
#  'cast': ['James Stewart', 'Grace Kelly', 'Wendell Corey', 'Thelma Ritter'],
#  'countries': ['USA'],
#  'directors': ['Alfred Hitchcock'],
#  'fullplot': 'Professional photographer L.B. "Jeff" Jeffries breaks his leg '
#              'while getting an action shot at an auto race. Confined to his '
#              'New York apartment, he spends his time looking out of the rear '
#              'window observing the neighbors. He begins to suspect that a man '
#              'across the courtyard may have murdered his wife. Jeff enlists '
#              'the help of his high society fashion-consultant girlfriend Lisa '
#              'Freemont and his visiting nurse Stella to investigate.',
#  'genres': ['Mystery', 'Thriller'],
#  'imdb': {'id': 47396, 'rating': 8.6, 'votes': 283273},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:31:57.327000000',
#  'num_mflix_comments': 1,
#  'plot': 'A wheelchair bound photographer spies on his neighbours from his '
#          'apartment window and becomes convinced one of them has committed '
#          'murder.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNGUxYWM3M2MtMGM3Mi00ZmRiLWE0NGQtZjE5ODI2OTJhNTU0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'runtime': 112,
#  'title': 'Rear Window',
#  'tomatoes': {'consensus': 'Hitchcock exerted full potential of suspense in '
#                            'this masterpiece.',
#               'critic': {'meter': 100, 'numReviews': 63, 'rating': 8.9},
#               'dvd': datetime.datetime(2001, 3, 6, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 7, 38),
#               'production': 'Paramount Pictures',
#               'rotten': 0,
#               'viewer': {'meter': 95, 'numReviews': 147500, 'rating': 4.2}},
#  'type': 'movie',
#  'writers': ['John Michael Hayes (screenplay)',
#              'Cornell Woolrich (based on the short story by)'],
#  'year': 1954}
# {'_id': ObjectId('573a1395f29313caabce144b'),
#  'awards': {'nominations': 5,
#             'text': 'Nominated for 4 Oscars. Another 7 wins & 5 nominations.',
#             'wins': 11},
#  'cast': ['Anthony Perkins', 'Vera Miles', 'John Gavin', 'Janet Leigh'],
#  'countries': ['USA'],
#  'directors': ['Alfred Hitchcock'],
#  'fullplot': 'Phoenix officeworker Marion Crane is fed up with the way life '
#              'has treated her. She has to meet her lover Sam in lunch breaks '
#              'and they cannot get married because Sam has to give most of his '
#              'money away in alimony. One Friday Marion is trusted to bank '
#              '$40,000 by her employer. Seeing the opportunity to take the '
#              'money and start a new life, Marion leaves town and heads towards '
#              "Sam's California store. Tired after the long drive and caught in "
#              'a storm, she gets off the main highway and pulls into The Bates '
#              'Motel. The motel is managed by a quiet young man called Norman '
#              'who seems to be dominated by his mother.',
#  'genres': ['Horror', 'Mystery', 'Thriller'],
#  'imdb': {'id': 54215, 'rating': 8.6, 'votes': 376318},
#  'languages': ['English'],
#  'lastupdated': '2015-09-04 00:05:08.977000000',
#  'num_mflix_comments': 0,
#  'plot': "A Phoenix secretary steals $40,000 from her employer's client, goes "
#          'on the run and checks into a remote motel run by a young man under '
#          'the domination of his mother.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNTQwNDM1YzItNDAxZC00NWY2LTk0M2UtNDIwNWI5OGUyNWUxXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1960, 9, 8, 0, 0),
#  'runtime': 109,
#  'title': 'Psycho',
#  'tomatoes': {'consensus': 'Infamous for its shower scene, but immortal for '
#                            'its contribution to the horror genre. Because '
#                            'Psycho was filmed with tact, grace, and art, '
#                            "Hitchcock didn't just create modern horror, he "
#                            'validated it.',
#               'critic': {'meter': 96, 'numReviews': 84, 'rating': 9.2},
#               'dvd': datetime.datetime(2001, 3, 6, 0, 0),
#               'fresh': 81,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 44, 21),
#               'production': 'Paramount Pictures',
#               'rotten': 3,
#               'viewer': {'meter': 94, 'numReviews': 236029, 'rating': 3.9}},
#  'type': 'movie',
#  'writers': ['Joseph Stefano (screenplay)', 'Robert Bloch (novel)'],
#  'year': 1960}
# {'_id': ObjectId('573a1396f29313caabce39e5'),
#  'awards': {'nominations': 4, 'text': '5 wins & 4 nominations.', 'wins': 5},
#  'cast': ['Claudia Cardinale',
#           'Henry Fonda',
#           'Jason Robards',
#           'Charles Bronson'],
#  'countries': ['Italy', 'USA', 'Spain'],
#  'directors': ['Sergio Leone'],
#  'fullplot': 'Story of a young woman, Mrs. McBain, who moves from New Orleans '
#              'to frontier Utah, on the very edge of the American West. She '
#              'arrives to find her new husband and family slaughtered, but by '
#              'whom? The prime suspect, coffee-lover Cheyenne, befriends her '
#              'and offers to go after the real killer, assassin gang leader '
#              'Frank, in her honor. He is accompanied by Harmonica, a man '
#              'already on a quest to get even.',
#  'genres': ['Western'],
#  'imdb': {'id': 64116, 'rating': 8.6, 'votes': 195109},
#  'languages': ['English', 'Spanish', 'Italian'],
#  'lastupdated': '2015-09-14 00:00:06.893000000',
#  'metacritic': 80,
#  'num_mflix_comments': 1,
#  'plot': 'Epic story of a mysterious stranger with a harmonica who joins '
#          'forces with a notorious desperado to protect a beautiful widow from '
#          'a ruthless assassin working for the railroad.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZGI5MjBmYzYtMzJhZi00NGI1LTk3MzItYjBjMzcxM2U3MDdiXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(1968, 12, 21, 0, 0),
#  'runtime': 175,
#  'title': 'Once Upon a Time in the West',
#  'tomatoes': {'consensus': 'A landmark Sergio Leone spaghetti western '
#                            'masterpiece featuring a classic Morricone score.',
#               'critic': {'meter': 98, 'numReviews': 54, 'rating': 9.0},
#               'dvd': datetime.datetime(2003, 11, 18, 0, 0),
#               'fresh': 53,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 53, 4),
#               'production': 'Paramount Pictures',
#               'rotten': 1,
#               'viewer': {'meter': 95, 'numReviews': 63662, 'rating': 4.3}},
#  'type': 'movie',
#  'writers': ['Sergio Donati (screenplay)',
#              'Sergio Leone (screenplay)',
#              'Dario Argento (from a story by)',
#              'Bernardo Bertolucci (from a story by)',
#              'Sergio Leone (from a story by)'],
#  'year': 1968}
# {'_id': ObjectId('573a1396f29313caabce4a9a'),
#  'awards': {'nominations': 19,
#             'text': 'Won 3 Oscars. Another 30 wins & 19 nominations.',
#             'wins': 33},
#  'cast': ['Marlon Brando', 'Al Pacino', 'James Caan', 'Richard S. Castellano'],
#  'countries': ['USA'],
#  'directors': ['Francis Ford Coppola'],
#  'fullplot': 'When the aging head of a famous crime family decides to transfer '
#              'his position to one of his subalterns, a series of unfortunate '
#              'events start happening to the family, and a war begins between '
#              'all the well-known families leading to insolence, deportation, '
#              'murder and revenge, and ends with the favorable successor being '
#              'finally chosen.',
#  'genres': ['Crime', 'Drama'],
#  'imdb': {'id': 68646, 'rating': 9.5, 'votes': 1038358},
#  'languages': ['English', 'Italian', 'Latin'],
#  'lastupdated': '2015-09-02 00:08:23.680000000',
#  'metacritic': 100,
#  'num_mflix_comments': 131,
#  'plot': 'The aging patriarch of an organized crime dynasty transfers control '
#          'of his clandestine empire to his reluctant son.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1972, 3, 24, 0, 0),
#  'runtime': 175,
#  'title': 'The Godfather',
#  'tomatoes': {'consensus': "One of Hollywood's greatest critical and "
#                            'commercial successes, The Godfather gets '
#                            'everything right; not only did the movie transcend '
#                            'expectations, it established new benchmarks for '
#                            'American cinema.',
#               'critic': {'meter': 99, 'numReviews': 84, 'rating': 9.2},
#               'dvd': datetime.datetime(2001, 10, 9, 0, 0),
#               'fresh': 83,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 15, 13),
#               'production': 'Paramount Pictures',
#               'rotten': 1,
#               'viewer': {'meter': 98, 'numReviews': 725773, 'rating': 4.4},
#               'website': 'http://www.thegodfather.com'},
#  'type': 'movie',
#  'writers': ['Mario Puzo (screenplay)',
#              'Francis Ford Coppola (screenplay)',
#              'Mario Puzo (novel)'],
#  'year': 1972}
# {'_id': ObjectId('573a1396f29313caabce557f'),
#  'awards': {'nominations': 16,
#             'text': 'Won 6 Oscars. Another 13 wins & 16 nominations.',
#             'wins': 19},
#  'cast': ['Al Pacino', 'Robert Duvall', 'Diane Keaton', 'Robert De Niro'],
#  'countries': ['USA'],
#  'directors': ['Francis Ford Coppola'],
#  'fullplot': 'The continuing saga of the Corleone crime family tells the story '
#              'of a young Vito Corleone growing up in Sicily and in 1910s New '
#              'York; and follows Michael Corleone in the 1950s as he attempts '
#              'to expand the family business into Las Vegas, Hollywood and '
#              'Cuba.',
#  'genres': ['Crime', 'Drama'],
#  'imdb': {'id': 71562, 'rating': 9.1, 'votes': 700857},
#  'languages': ['English', 'Italian', 'Spanish', 'Latin', 'Sicilian'],
#  'lastupdated': '2015-09-02 00:15:27.537000000',
#  'metacritic': 80,
#  'num_mflix_comments': 0,
#  'plot': 'The early life and career of Vito Corleone in 1920s New York is '
#          'portrayed while his son, Michael, expands and tightens his grip on '
#          'his crime syndicate stretching from Lake Tahoe, Nevada to '
#          'pre-revolution 1958 Cuba.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1974, 12, 20, 0, 0),
#  'runtime': 200,
#  'title': 'The Godfather: Part II',
#  'tomatoes': {'consensus': 'Drawing on strong performances by Al Pacino and '
#                            "Robert De Niro, Francis Ford Coppola's "
#                            "continuation of Mario Puzo's Mafia saga set new "
#                            'standards for sequels that have yet to be matched '
#                            'or broken.',
#               'critic': {'meter': 97, 'numReviews': 72, 'rating': 9.5},
#               'dvd': datetime.datetime(2005, 5, 24, 0, 0),
#               'fresh': 70,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 17, 0, 43),
#               'production': 'Paramount Pictures',
#               'rotten': 2,
#               'viewer': {'meter': 97, 'numReviews': 407106, 'rating': 4.3},
#               'website': 'http://www.thegodfather.com/'},
#  'type': 'movie',
#  'writers': ['Francis Ford Coppola (screenplay)',
#              'Mario Puzo (screenplay)',
#              'Mario Puzo (based on the novel "The Godfather" by)'],
#  'year': 1974}

# %% [markdown]
# 4. Write a query to find all movies where the genre contains both "Action" and "Adventure

# %%
action_adventure_movies = collection.find({'genres': {'$all': ['Action', 'Adventure']}}).limit(5)

for movie in action_adventure_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1394f29313caabcde77d'),
#  'awards': {'nominations': 1,
#             'text': 'Won 2 Oscars. Another 2 wins & 1 nomination.',
#             'wins': 4},
#  'cast': ['Deborah Kerr', 'Stewart Granger', 'Richard Carlson', 'Hugo Haas'],
#  'countries': ['USA'],
#  'directors': ['Compton Bennett', 'Andrew Marton'],
#  'fullplot': 'Guide Allan Quatermain helps a young lady (Beth) find her lost '
#              "husband somewhere in Africa. It's a spectacular adventure story "
#              'with romance, because while they fight with wild animals and '
#              'cannibals, they fall in love. Will they find the lost husband '
#              'and finish the nice connection?',
#  'genres': ['Adventure', 'Romance', 'Action'],
#  'imdb': {'id': 42646, 'rating': 6.9, 'votes': 4128},
#  'languages': ['English'],
#  'lastupdated': '2015-08-06 00:32:20.070000000',
#  'num_mflix_comments': 1,
#  'plot': 'Adventurer Allan Quartermain leads an expedition into uncharted '
#          'African territory in an attempt to locate an explorer who went '
#          'missing during his search for the fabled diamond mines of King '
#          'Solomon.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjZlOWFjNzktMDQ3OC00ODQxLWEzZjMtN2E0Y2MwM2FkMzE0XkEyXkFqcGdeQXVyNTEwNDcxNDc@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1950, 11, 24, 0, 0),
#  'runtime': 103,
#  'title': "King Solomon's Mines",
#  'tomatoes': {'critic': {'meter': 92, 'numReviews': 12, 'rating': 7.2},
#               'dvd': datetime.datetime(2005, 1, 11, 0, 0),
#               'fresh': 11,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 19, 11, 25),
#               'production': 'MGM Home Entertainment',
#               'rotten': 1,
#               'viewer': {'meter': 60, 'numReviews': 3186, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['Helen Deutsch (screenplay)', 'H. Rider Haggard (novel)'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcdf465'),
#  'awards': {'nominations': 4,
#             'text': 'Nominated for 2 Oscars. Another 2 nominations.',
#             'wins': 0},
#  'cast': ['Robert Taylor', 'Ava Gardner', 'Mel Ferrer', 'Anne Crawford'],
#  'countries': ['USA'],
#  'directors': ['Richard Thorpe'],
#  'fullplot': 'King Arthur establishes the greatest reign England has ever '
#              'seen, and along for the ride are his indispensable Knights of '
#              'the Round Table, particularly Sir Lancelot. Then, Arthur finds '
#              'himself a bride, the beautiful Guenivere. While she loves '
#              'Arthur, she also loves Lancelot and though Lancelot repeatedly '
#              'fights it, he loves her, too. Treachery is brewing as the evil '
#              'Morgan le Fay and her knight Sir Modred work to trap them. So '
#              'begins the decline and eventual fall of Arthur and Camelot.',
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 45966, 'rating': 6.3, 'votes': 2262},
#  'languages': ['English'],
#  'lastupdated': '2015-09-13 00:15:19.830000000',
#  'num_mflix_comments': 0,
#  'plot': "King Arthur's rule is threatened by the adulterous love between Sir "
#          "Lancelot and Queen Guinevere, a relationship the king's enemies hope "
#          'to exploit.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjQyMmIyODMtYWU3YS00NTMzLWI3OTAtOWVlNzczMTc1NjQ4XkEyXkFqcGdeQXVyNjQzNDI3NzY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1954, 1, 15, 0, 0),
#  'runtime': 115,
#  'title': 'Knights of the Round Table',
#  'tomatoes': {'critic': {'meter': 80, 'numReviews': 5, 'rating': 6.2},
#               'dvd': datetime.datetime(2003, 7, 1, 0, 0),
#               'fresh': 4,
#               'lastUpdated': datetime.datetime(2015, 8, 4, 20, 11, 1),
#               'production': 'Metro-Goldwyn-Mayer (MGM)',
#               'rotten': 1,
#               'viewer': {'meter': 44, 'numReviews': 2883, 'rating': 3.1}},
#  'type': 'movie',
#  'writers': ['Talbot Jennings (screenplay)',
#              'Jan Lustig (screenplay)',
#              'Noel Langley (screenplay)',
#              'Thomas Malory (based on "Le Morte D\'Arthur")'],
#  'year': 1953}
# {'_id': ObjectId('573a1394f29313caabcde7ee'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Errol Flynn', 'Alexis Smith', 'S.Z. Sakall', 'Douglas Kennedy'],
#  'countries': ['USA'],
#  'directors': ['Ray Enright', 'Raoul Walsh'],
#  'fullplot': 'Australian sheep-man Morgan Lane comes to Montana looking for '
#              'government-owned grazing land, and encamps his sheep at the '
#              'boundary line (where the bad grazing ends and the good grazing '
#              'begins) set up by the cattle barons to keep the sheep from '
#              'nubbing away at the good grass. He goes to town, posing as a '
#              'merchant, explains his Australian accent, and learns that Maria '
#              'Singleton, owner of a large ranch, and Rodney Ackroyd (who never '
#              'explains where he got his name), another ranch owner and Miss '
#              "Singleton's fiancèe, are the leaders of the cattlemen against "
#              'the sheep-men. Romance tugs at Morgan and Miss Singleton, who '
#              'quickly decides that Morgan has a much better name than Rodney '
#              '(and other attributes) but the cattle-vs.-sheep feud keeps them '
#              'apart. Until they meet in the street for a showdown gunfight '
#              'following a disastrous clash between the cattle and sheep '
#              'factions.',
#  'genres': ['Action', 'Adventure', 'Romance'],
#  'imdb': {'id': 42744, 'rating': 6.2, 'votes': 759},
#  'languages': ['English'],
#  'lastupdated': '2015-09-17 04:39:05.470000000',
#  'num_mflix_comments': 1,
#  'plot': 'An Australian sheepman comes to Montana looking for grazing space, '
#          'is opposed by local ranchers and a wealthy cattle-woman.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTEyNjI3MTQzMTZeQTJeQWpwZ15BbWU4MDExNjA5MDMx._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1950, 1, 28, 0, 0),
#  'runtime': 76,
#  'title': 'Montana',
#  'tomatoes': {'dvd': datetime.datetime(2008, 8, 26, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 26, 18, 0, 15),
#               'production': 'Warner Home Video',
#               'viewer': {'meter': 30, 'numReviews': 81, 'rating': 2.9}},
#  'type': 'movie',
#  'writers': ['James R. Webb (screenplay)',
#              'Borden Chase (screenplay)',
#              "Charles O'Neal (screenplay)",
#              'Ernest Haycox (story)'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcdf488'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Leo Gorcey', 'Huntz Hall', 'Bernard Gorcey', 'Angela Greene'],
#  'countries': ['USA'],
#  'directors': ['Edward Bernds'],
#  'fullplot': 'Word comes to the Bowery that titled, great, great grand-uncle '
#              'of Horace Debussy Jones, better known as Sach, is near death and '
#              'has provided transportation to summon relatives from around the '
#              'world. Sach and the Bowery Boys, Slip Mahoney, Butch Williams, '
#              'Chuck Anderson and Soda Shoppe owner Louie Dumbrowsky, trade '
#              "Sach's pre-paid first class ticket for lesser (much lesser) "
#              'accommodations and embark for ye olde London towne. There, they '
#              'find the old man, the Earl of Walsingham already surrounded by '
#              'sinister Sir Edgar Whipsnade; Reggie, the obligatory Fop; the '
#              'spinster Aunt Agatha; the young and seductive Lady Marcia; '
#              'moronic Cousin Herbert, and Hoskins, the Butler. They, of '
#              'course,are assembled in a plot to slowly poison the old Earl and '
#              'to get rid of Sach and his pals.',
#  'genres': ['Action', 'Adventure', 'Comedy'],
#  'imdb': {'id': 46011, 'rating': 7.0, 'votes': 182},
#  'languages': ['English'],
#  'lastupdated': '2015-07-08 09:09:49.550000000',
#  'num_mflix_comments': 0,
#  'plot': 'The Bowery Boys find themselves in London, in an old mansion '
#          'complete with a dungeon, an ominous bell tower and the ghost of an '
#          'old hangman.',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1953, 5, 24, 0, 0),
#  'runtime': 62,
#  'title': 'Loose in London',
#  'tomatoes': {'consensus': "Ophèls' graceful camerawork and visual portrayal "
#                            'of luxury and loss make Earrings a powerful French '
#                            'drama.',
#               'critic': {'meter': 100, 'numReviews': 33, 'rating': 8.9},
#               'dvd': datetime.datetime(2008, 9, 16, 0, 0),
#               'fresh': 33,
#               'lastUpdated': datetime.datetime(2015, 8, 20, 18, 53, 38),
#               'production': 'Criterion Collection',
#               'rotten': 0,
#               'viewer': {'meter': 92, 'numReviews': 1847, 'rating': 4.3}},
#  'type': 'movie',
#  'writers': ['Edward Bernds (screenplay)', 'Elwood Ullman (screenplay)'],
#  'year': 1953}
# {'_id': ObjectId('573a1394f29313caabcdf340'),
#  'awards': {'nominations': 0,
#             'text': 'Nominated for 1 Oscar. Another 1 win.',
#             'wins': 2},
#  'cast': ['Richard Burton', 'James Mason', 'Robert Newton', 'Robert Douglas'],
#  'countries': ['USA'],
#  'directors': ['Robert Wise'],
#  'fullplot': 'Rommel has the British in retreat on his way to the Suez Canal. '
#              'All that stands in his way is Tobruk, held by a vastly out '
#              'numbered force of Australian troops. Richard Burton leads these '
#              'troops on daring raids against Rommel, keeping him off balance '
#              "as they earn the nickname 'The Desert Rats'.",
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 45679, 'rating': 6.8, 'votes': 3379},
#  'languages': ['English', 'German'],
#  'lastupdated': '2015-08-29 00:03:46.110000000',
#  'num_mflix_comments': 1,
#  'plot': 'Richard Burton plays a Scottish Army officer put in charge of a '
#          'disparate band of ANZAC troops on the perimeter of Tobruk with the '
#          'German Army doing their best to dislodge them.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNjViMWZhYzUtNGM4Ni00ZjQ2LWExNTEtN2M1OTA2NDUyODMwL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjQzNDI3NzY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1953, 5, 20, 0, 0),
#  'runtime': 88,
#  'title': 'The Desert Rats',
#  'tomatoes': {'critic': {'meter': 80, 'numReviews': 5, 'rating': 6.3},
#               'dvd': datetime.datetime(2002, 5, 21, 0, 0),
#               'fresh': 4,
#               'lastUpdated': datetime.datetime(2015, 9, 1, 19, 13, 4),
#               'production': 'Fox',
#               'rotten': 1,
#               'viewer': {'meter': 71, 'numReviews': 1524, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Richard Murphy'],
#  'year': 1953}

# %% [markdown]
# #2
# 1. Write a query to find all movies where the genre is "Comedy" and sort them by IMDb rating in descending order (Return the first 5 results).

# %%
sorted_comedy_movies = collection.find({'genres': 'Comedy'}).sort('imdb.rating', -1).limit(5)

for movie in sorted_comedy_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13dff29313caabdb909e'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Jessie Barr',
#           'Louis Cancelmi',
#           'Margaret Daly',
#           'Caitlin FitzGerald'],
#  'countries': ['USA'],
#  'directors': ["Tom O'Brien"],
#  'fullplot': 'Danny, a commercial editor and documentary filmmaker attempts to '
#              'finish his film, a study on relationship while navigating the '
#              'relationships in his own life. Will he continue to chase the '
#              'unattainable Theresa a hippy new age dancer(Caitlin Fitzgerald) '
#              "or will he finally admit he's in love with his best friend Carla "
#              '(Katherine Waterston) who is in an unfulfilling relationship '
#              'with a political strategist(Gaby Hoffman). Manhattan Romance is '
#              'a funny insightful look at contemporary life in Manhattan. It '
#              'explores new age ideas and open relationship as well as true '
#              'friendship and connection.',
#  'genres': ['Comedy', 'Drama', 'Romance'],
#  'imdb': {'id': 2608324, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-28 00:17:01.610000000',
#  'num_mflix_comments': 0,
#  'plot': 'Danny, a commercial editor and documentary filmmaker attempts to '
#          'finish his film, a study on relationship while navigating the '
#          'relationships in his own life. Will he continue to chase the ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjMzODk2MDc0MF5BMl5BanBnXkFtZTgwMTc3NjU4NjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 10, 2, 0, 0),
#  'runtime': 94,
#  'title': 'Manhattan Romance',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 2, 18, 57, 41),
#               'viewer': {'numReviews': 2, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ["Tom O'Brien"],
#  'year': 2015}
# {'_id': ObjectId('573a13d9f29313caabdaa62d'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Ray Panthaki', 'Vicky McClure', 'Adeel Akhtar', 'Jenny Bede'],
#  'countries': ['UK'],
#  'directors': ['Keri Collins'],
#  'fullplot': 'Two convenience store robbers mess up the crime and end up '
#              'working there for the rest of the night.',
#  'genres': ['Comedy'],
#  'imdb': {'id': 2263210, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-09-14 17:30:41.583000000',
#  'num_mflix_comments': 0,
#  'plot': 'Two convenience store robbers mess up the crime and end up working '
#          'there for the rest of the night.',
#  'released': datetime.datetime(2015, 10, 2, 0, 0),
#  'title': 'Convenience',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 13, 9, 52, 44),
#               'viewer': {'numReviews': 3, 'rating': 4.0},
#               'website': 'http://www.convenience-movie.com'},
#  'type': 'movie',
#  'writers': ['Simon Fantauzzo'],
#  'year': 2015}
# {'_id': ObjectId('573a13def29313caabdb627d'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Gracie Mei Huntsman',
#           'Jon Huntsman',
#           'Jerome A. Cohen',
#           'Chen Guangcheng'],
#  'countries': ['China', 'USA'],
#  'directors': ['Vanessa Hope'],
#  'genres': ['Documentary', 'Comedy', 'History'],
#  'imdb': {'id': 2505376, 'rating': '', 'votes': ''},
#  'languages': ['English', 'Chinese'],
#  'lastupdated': '2015-08-26 01:05:17.383000000',
#  'num_mflix_comments': 1,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjAyNzYzNzIyM15BMl5BanBnXkFtZTgwMjA4ODgxNTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 4, 20, 0, 0),
#  'runtime': 90,
#  'title': 'All Eyes and Ears',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 6, 26, 18, 3, 5),
#               'viewer': {'numReviews': 1, 'rating': 1.5}},
#  'type': 'movie',
#  'writers': ['Vanessa Hope'],
#  'year': 2015}
# {'_id': ObjectId('573a13dcf29313caabdb2dec'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Jennifer Jason Leigh', 'David Thewlis', 'Tom Noonan'],
#  'countries': ['USA'],
#  'directors': ['Duke Johnson', 'Charlie Kaufman'],
#  'fullplot': "Charlie Kaufman's first stop-motion film about a man crippled by "
#              'the mundanity of his life.',
#  'genres': ['Animation', 'Comedy', 'Fantasy'],
#  'imdb': {'id': 2401878, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:00:23.967000000',
#  'num_mflix_comments': 0,
#  'plot': "Charlie Kaufman's first stop-motion film about a man crippled by the "
#          'mundanity of his life.',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 9, 8, 0, 0),
#  'runtime': 90,
#  'title': 'Anomalisa',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 26, 18, 15, 38),
#               'production': 'Walt Disney Pictures International',
#               'viewer': {'numReviews': 12, 'rating': 2.5}},
#  'type': 'movie',
#  'writers': ['Charlie Kaufman'],
#  'year': 2015}
# {'_id': ObjectId('573a13cff29313caabd88f5b'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Halston Sage',
#           'Tye Sheridan',
#           'Patrick Schwarzenegger',
#           'Cloris Leachman'],
#  'countries': ['USA'],
#  'directors': ['Christopher Landon'],
#  'fullplot': 'Three scouts, on the eve of their last camp-out, discover the '
#              'true meaning of friendship when they attempt to save their town '
#              'from a zombie outbreak.',
#  'genres': ['Comedy', 'Horror'],
#  'imdb': {'id': 1727776, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-27 00:00:19.697000000',
#  'num_mflix_comments': 0,
#  'plot': 'Three scouts, on the eve of their last camp-out, discover the true '
#          'meaning of friendship when they attempt to save their town from a '
#          'zombie outbreak.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY4NjczNjE4OV5BMl5BanBnXkFtZTgwODk0MjQ5NjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 10, 30, 0, 0),
#  'runtime': 93,
#  'title': 'Scouts Guide to the Zombie Apocalypse',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 30, 20, 13, 8),
#               'production': 'Paramount Pictures',
#               'viewer': {'numReviews': 91, 'rating': 2.8},
#               'website': 'http://www.scoutsandzombiesmovie.com/'},
#  'type': 'movie',
#  'writers': ['Emi Mochizuki (screenplay)',
#              'Carrie Lee Wilson (screenplay)',
#              'Christopher Landon (screenplay)',
#              'Lona Williams (screenplay)'],
#  'year': 2015}

# %% [markdown]
# 2. Write a query to find all movies where the genre is "Drama" and sort them by release year in ascending order.

# %%
sorted_drama_movies = collection.find({'genres': 'Drama'}).sort('year', 1).limit(5)

for movie in sorted_drama_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1394f29313caabcde630'),
#  'awards': {'nominations': 1,
#             'text': 'Nominated for 3 Oscars. Another 1 win & 1 nomination.',
#             'wins': 4},
#  'cast': ['Eleanor Parker', 'Agnes Moorehead', 'Ellen Corby', 'Hope Emerson'],
#  'countries': ['USA'],
#  'directors': ['John Cromwell'],
#  'genres': ['Crime', 'Drama', 'Film-Noir'],
#  'imdb': {'id': 42296, 'rating': 7.8, 'votes': 2189},
#  'languages': ['English'],
#  'lastupdated': '2015-09-15 04:50:38.620000000',
#  'num_mflix_comments': 0,
#  'plot': 'A naive nineteen year old widow becomes coarsened and cynical when '
#          "she is sent to a woman's prison and is exposed to hardened criminals "
#          'and sadistic guards.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNGVkNTkxMDItNWYxZi00NGE2LTk5Y2YtODRhMzcwN2E4YjkyXkEyXkFqcGdeQXVyNTEwNDcxNDc@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1950, 5, 19, 0, 0),
#  'runtime': 96,
#  'title': 'Caged',
#  'tomatoes': {'dvd': datetime.datetime(2007, 6, 26, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 13, 9, 54, 12),
#               'production': 'Warner Bros. Pictures',
#               'viewer': {'meter': 85, 'numReviews': 578, 'rating': 3.9}},
#  'type': 'movie',
#  'writers': ['Virginia Kellogg (screenplay)',
#              'Virginia Kellogg (story)',
#              'Bernard C. Schoenfeld (story)'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcde921'),
#  'awards': {'nominations': 0,
#             'text': 'Nominated for 1 Oscar. Another 1 win.',
#             'wins': 2},
#  'cast': ['James Hayter', 'Kathleen Harrison', 'Felix Aylmer', 'Lana Morris'],
#  'countries': ['UK'],
#  'directors': ['Ken Annakin', 'Harold French'],
#  'fullplot': 'Three short stories are introduced by author W. Somerset Maugham '
#              'in the second of his anthology film trilogy. In "The Verger," a '
#              'church verger of seventeen years is fired by his new '
#              "straight-laced vicar when it's discovered that he cannot read or "
#              'write. Forced to make life-altering decisions, the life-long '
#              'bachelor proposes to his landlady and becomes an entrepreneur. '
#              'In "Mr. Know-All" an obnoxiously pushy and irrepressibly boorish '
#              'dealer in jewelry alienates all his fellow passengers on an '
#              'ocean cruise despite his cheerful nature and generosity, but '
#              'later is sensitive enough to realize that sacrificing his ego at '
#              'a key moment is important to a woman\'s happiness. "The '
#              'Sanatorium" revolves around the lives of tuberculosis patients '
#              'at an exclusive Scottish sanatorium including a pair of doomed '
#              'lovers who choose quality over quantity of life.',
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 42752, 'rating': 7.3, 'votes': 408},
#  'languages': ['English'],
#  'lastupdated': '2015-09-03 00:44:21.537000000',
#  'num_mflix_comments': 1,
#  'plot': 'Three short stories by W. Somerset Maugham, "The Verger," "Mr. '
#          'Know-All," and "The Sanatorium," are introduced by the author.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTg0NDA5NjAyNl5BMl5BanBnXkFtZTcwOTU1OTc3MQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1950, 12, 20, 0, 0),
#  'runtime': 91,
#  'title': 'Trio',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 6, 27, 18, 42, 24),
#               'viewer': {'meter': 40, 'numReviews': 27, 'rating': 3.0}},
#  'type': 'movie',
#  'writers': ['Noel Langley',
#              'W. Somerset Maugham (screenplay)',
#              'W. Somerset Maugham (stories)',
#              'R.C. Sherriff'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcde7ea'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Betty Grable', 'Dan Dailey', 'David Wayne', 'Jane Wyatt'],
#  'countries': ['USA'],
#  'directors': ['Henry Koster'],
#  'fullplot': 'Radio star Kitty Moran, long married to partner Jack, finds '
#              "she's pregnant, but miscarries. For a change, the couple turn "
#              'their act into a series on early TV and try to adopt a baby, '
#              'finally acquiring a girl in a somewhat back alley manner. '
#              'Complications follow amid a series of musical numbers.',
#  'genres': ['Drama', 'Musical'],
#  'imdb': {'id': 42767, 'rating': 6.3, 'votes': 309},
#  'languages': ['English'],
#  'lastupdated': '2015-05-19 01:53:03.770000000',
#  'num_mflix_comments': 0,
#  'plot': 'Betty Grable and Dan Dailey are a married song and dance team who '
#          'cannot have children. The movie follows the travails as they try and '
#          'adopt and keep the kids they adopt while performing on their TV '
#          'show.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZWU4MzIxN2UtZmQzYS00MzAxLTljYzctZGI2MzZmZDQ0NzllXkEyXkFqcGdeQXVyNjc0MzMzNjA@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1950, 12, 18, 0, 0),
#  'runtime': 96,
#  'title': 'My Blue Heaven',
#  'tomatoes': {'dvd': datetime.datetime(2006, 6, 13, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 3, 18, 34, 29),
#               'production': '20th Century Fox Film Corporation',
#               'viewer': {'meter': 64, 'numReviews': 183, 'rating': 3.8}},
#  'type': 'movie',
#  'writers': ['Claude Binyon', 'S.K. Lauren (story)', 'Lamar Trotti'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcde897'),
#  'awards': {'nominations': 0,
#             'text': 'Nominated for 1 Oscar. Another 1 win.',
#             'wins': 2},
#  'cast': ['James Hayter', 'Kathleen Harrison', 'Felix Aylmer', 'Lana Morris'],
#  'countries': ['UK'],
#  'directors': ['Ken Annakin', 'Harold French'],
#  'fullplot': 'Three short stories are introduced by author W. Somerset Maugham '
#              'in the second of his anthology film trilogy. In "The Verger," a '
#              'church verger of seventeen years is fired by his new '
#              "straight-laced vicar when it's discovered that he cannot read or "
#              'write. Forced to make life-altering decisions, the life-long '
#              'bachelor proposes to his landlady and becomes an entrepreneur. '
#              'In "Mr. Know-All" an obnoxiously pushy and irrepressibly boorish '
#              'dealer in jewelry alienates all his fellow passengers on an '
#              'ocean cruise despite his cheerful nature and generosity, but '
#              'later is sensitive enough to realize that sacrificing his ego at '
#              'a key moment is important to a woman\'s happiness. "The '
#              'Sanatorium" revolves around the lives of tuberculosis patients '
#              'at an exclusive Scottish sanatorium including a pair of doomed '
#              'lovers who choose quality over quantity of life.',
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 42752, 'rating': 7.3, 'votes': 408},
#  'languages': ['English'],
#  'lastupdated': '2015-09-03 00:38:33.180000000',
#  'num_mflix_comments': 0,
#  'plot': 'Three short stories by W. Somerset Maugham, "The Verger," "Mr. '
#          'Know-All," and "The Sanatorium," are introduced by the author.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTg0NDA5NjAyNl5BMl5BanBnXkFtZTcwOTU1OTc3MQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1950, 12, 20, 0, 0),
#  'runtime': 91,
#  'title': 'Trio',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 6, 27, 18, 42, 24),
#               'viewer': {'meter': 40, 'numReviews': 27, 'rating': 3.0}},
#  'type': 'movie',
#  'writers': ['Noel Langley',
#              'W. Somerset Maugham (screenplay)',
#              'W. Somerset Maugham (stories)',
#              'R.C. Sherriff'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcde631'),
#  'awards': {'nominations': 9,
#             'text': 'Won 1 Oscar. Another 4 wins & 9 nominations.',
#             'wins': 5},
#  'cast': ['Judy Holliday',
#           'Broderick Crawford',
#           'William Holden',
#           'Howard St. John'],
#  'countries': ['USA'],
#  'directors': ['George Cukor'],
#  'fullplot': 'Uncouth, loud-mouth junkyard tycoon Harry Brock descends upon '
#              'Washington D.C. to buy himself a congressman or two, bringing '
#              'with him his mistress, ex-showgirl Billie Dawn. Brock hires '
#              'newspaperman Paul Verrall to see if he can soften her rough '
#              'edges and make her more presentable in capital society. But '
#              "Harry gets more than he bargained for as Billie absorbs Verall's "
#              'lessons in U.S. history and not only comes to the realization '
#              'that Harry is nothing but a two-bit, corrupt crook, but in the '
#              'process also falls in love with her handsome tutor.',
#  'genres': ['Comedy', 'Drama', 'Romance'],
#  'imdb': {'id': 42276, 'rating': 7.7, 'votes': 7120},
#  'languages': ['English'],
#  'lastupdated': '2015-09-15 04:49:13.510000000',
#  'num_mflix_comments': 0,
#  'plot': 'A million dollar Tycoon hires a tutor to teach his lover proper '
#          'etiquette.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BODBhOTdkMGYtMzRkYS00ZGU2LThlMjItMzRiNjAxMzNjMWRjXkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1951, 5, 28, 0, 0),
#  'runtime': 103,
#  'title': 'Born Yesterday',
#  'tomatoes': {'critic': {'meter': 95, 'numReviews': 21, 'rating': 8.2},
#               'dvd': datetime.datetime(2000, 2, 15, 0, 0),
#               'fresh': 20,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 18, 52, 55),
#               'production': 'Columbia Pictures',
#               'rotten': 1,
#               'viewer': {'meter': 86, 'numReviews': 4650, 'rating': 3.9}},
#  'type': 'movie',
#  'writers': ['Garson Kanin (play)', 'Albert Mannheimer (screenplay)'],
#  'year': 1950}

# %% [markdown]
# #3
# 1. Write an aggregation pipeline that calculates the average IMDb rating for each genre (Return the top 5 genres)

# %%
avg_rating_by_genre = collection.aggregate([
    {'$unwind': '$genres'},
    {'$group': {'_id': '$genres', 'avg_rating': {'$avg': '$imdb.rating'}}},
    {'$sort': {'avg_rating': -1}},
    {'$limit': 5}
])

for genre in avg_rating_by_genre:
    pprint.pprint(genre)
# Out:
# {'_id': 'Film-Noir', 'avg_rating': 7.396774193548388}
# {'_id': 'Short', 'avg_rating': 7.390625}
# {'_id': 'Documentary', 'avg_rating': 7.365130483064964}
# {'_id': 'News', 'avg_rating': 7.252272727272728}
# {'_id': 'History', 'avg_rating': 7.171942446043165}

# %% [markdown]
# 2. Write an aggregation pipeline to find the top 5 directors by the average IMDb rating of their movies.

# %%
top_directors = collection.aggregate([
    {'$unwind': '$directors'},
    {'$group': {'_id': '$directors', 'avg_rating': {'$avg': '$imdb.rating'}}},
    {'$sort': {'avg_rating': -1}},
    {'$limit': 5}
])

for director in top_directors:
    pprint.pprint(director)
# Out:
# {'_id': 'Sara Hirsh Bordo', 'avg_rating': 9.4}
# {'_id': 'Kevin Derek', 'avg_rating': 9.3}
# {'_id': 'Michael Benson', 'avg_rating': 9.0}
# {'_id': 'Slobodan Sijan', 'avg_rating': 8.95}
# {'_id': 'Sundar C.', 'avg_rating': 8.9}

# %% [markdown]
# 3. Write an aggregation pipeline to calculate the total number of movies released in each year (Sort results by year)

# %%
movies_per_year = collection.aggregate([
    {'$group': {'_id': '$year', 'count': {'$sum': 1}}},
    {'$sort': {'_id': 1}}
])

for year in movies_per_year:
    pprint.pprint(year)
# Out:
# {'_id': 1950, 'count': 55}
# {'_id': 1951, 'count': 54}
# {'_id': 1952, 'count': 45}
# {'_id': 1953, 'count': 65}
# {'_id': 1954, 'count': 47}
# {'_id': 1955, 'count': 67}
# {'_id': 1956, 'count': 67}
# {'_id': 1957, 'count': 71}
# {'_id': 1958, 'count': 75}
# {'_id': 1959, 'count': 71}
# {'_id': 1960, 'count': 73}
# {'_id': 1961, 'count': 68}
# {'_id': 1962, 'count': 70}
# {'_id': 1963, 'count': 69}
# {'_id': 1964, 'count': 86}
# {'_id': 1965, 'count': 77}
# {'_id': 1966, 'count': 87}
# {'_id': 1967, 'count': 81}
# {'_id': 1968, 'count': 89}
# {'_id': 1969, 'count': 107}
# {'_id': 1970, 'count': 120}
# {'_id': 1971, 'count': 106}
# {'_id': 1972, 'count': 121}
# {'_id': 1973, 'count': 112}
# {'_id': 1974, 'count': 103}
# {'_id': 1975, 'count': 107}
# {'_id': 1976, 'count': 116}
# {'_id': 1977, 'count': 123}
# {'_id': 1978, 'count': 128}
# {'_id': 1979, 'count': 131}
# {'_id': 1980, 'count': 167}
# {'_id': 1981, 'count': 168}
# {'_id': 1982, 'count': 177}
# {'_id': 1983, 'count': 161}
# {'_id': 1984, 'count': 199}
# {'_id': 1985, 'count': 189}
# {'_id': 1986, 'count': 190}
# {'_id': 1987, 'count': 222}
# {'_id': 1988, 'count': 251}
# {'_id': 1989, 'count': 232}
# {'_id': 1990, 'count': 225}
# {'_id': 1991, 'count': 238}
# {'_id': 1992, 'count': 270}
# {'_id': 1993, 'count': 274}
# {'_id': 1994, 'count': 305}
# {'_id': 1995, 'count': 372}
# {'_id': 1996, 'count': 407}
# {'_id': 1997, 'count': 439}
# {'_id': 1998, 'count': 513}
# {'_id': 1999, 'count': 515}
# {'_id': 2000, 'count': 581}
# {'_id': 2001, 'count': 612}
# {'_id': 2002, 'count': 622}
# {'_id': 2003, 'count': 603}
# {'_id': 2004, 'count': 678}
# {'_id': 2005, 'count': 713}
# {'_id': 2006, 'count': 774}
# {'_id': 2007, 'count': 810}
# {'_id': 2008, 'count': 886}
# {'_id': 2009, 'count': 917}
# {'_id': 2010, 'count': 866}
# {'_id': 2011, 'count': 893}
# {'_id': 2012, 'count': 955}
# {'_id': 2013, 'count': 1105}
# {'_id': 2014, 'count': 1073}
# {'_id': 2015, 'count': 480}
# {'_id': 2016, 'count': 1}
# {'_id': '1981è', 'count': 1}
# {'_id': '1986è', 'count': 1}
# {'_id': '1987è', 'count': 1}
# {'_id': '1988è', 'count': 1}
# {'_id': '1994è1998', 'count': 1}
# {'_id': '1995è', 'count': 1}
# {'_id': '1996è', 'count': 1}
# {'_id': '1997è', 'count': 2}
# {'_id': '1999è', 'count': 1}
# {'_id': '2000è', 'count': 1}
# {'_id': '2002è', 'count': 1}
# {'_id': '2003è', 'count': 1}
# {'_id': '2005è', 'count': 2}
# {'_id': '2006è', 'count': 1}
# {'_id': '2006è2007', 'count': 1}
# {'_id': '2006è2012', 'count': 2}
# {'_id': '2007è', 'count': 3}
# {'_id': '2009è', 'count': 2}
# {'_id': '2010è', 'count': 4}
# {'_id': '2011è', 'count': 2}
# {'_id': '2012è', 'count': 3}
# {'_id': '2014è', 'count': 2}

# %% [markdown]
# #4
# 1. Write a query to update the IMDb rating of a movie with the title "The Godfather"

# %%
collection.update_one({'title': 'The Godfather'}, {'$set': {'imdb.rating': 9.5}})

pprint.pprint(collection.find_one({'title': 'The Godfather'}))
# Out:
# {'_id': ObjectId('573a1396f29313caabce4a9a'),
#  'awards': {'nominations': 19,
#             'text': 'Won 3 Oscars. Another 30 wins & 19 nominations.',
#             'wins': 33},
#  'cast': ['Marlon Brando', 'Al Pacino', 'James Caan', 'Richard S. Castellano'],
#  'countries': ['USA'],
#  'directors': ['Francis Ford Coppola'],
#  'fullplot': 'When the aging head of a famous crime family decides to transfer '
#              'his position to one of his subalterns, a series of unfortunate '
#              'events start happening to the family, and a war begins between '
#              'all the well-known families leading to insolence, deportation, '
#              'murder and revenge, and ends with the favorable successor being '
#              'finally chosen.',
#  'genres': ['Crime', 'Drama'],
#  'imdb': {'id': 68646, 'rating': 9.5, 'votes': 1038358},
#  'languages': ['English', 'Italian', 'Latin'],
#  'lastupdated': '2015-09-02 00:08:23.680000000',
#  'metacritic': 100,
#  'num_mflix_comments': 131,
#  'plot': 'The aging patriarch of an organized crime dynasty transfers control '
#          'of his clandestine empire to his reluctant son.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1972, 3, 24, 0, 0),
#  'runtime': 175,
#  'title': 'The Godfather',
#  'tomatoes': {'consensus': "One of Hollywood's greatest critical and "
#                            'commercial successes, The Godfather gets '
#                            'everything right; not only did the movie transcend '
#                            'expectations, it established new benchmarks for '
#                            'American cinema.',
#               'critic': {'meter': 99, 'numReviews': 84, 'rating': 9.2},
#               'dvd': datetime.datetime(2001, 10, 9, 0, 0),
#               'fresh': 83,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 15, 13),
#               'production': 'Paramount Pictures',
#               'rotten': 1,
#               'viewer': {'meter': 98, 'numReviews': 725773, 'rating': 4.4},
#               'website': 'http://www.thegodfather.com'},
#  'type': 'movie',
#  'writers': ['Mario Puzo (screenplay)',
#              'Francis Ford Coppola (screenplay)',
#              'Mario Puzo (novel)'],
#  'year': 1972}

# %% [markdown]
# 2. Write a query to update all movies where the genre is "Horror" and set their IMDb rating to 6.0 if it is currently null.

# %%
collection.update_many({'genres': 'Horror', 'imdb.rating': None}, {'$set': {'imdb.rating': 6.0}})

horror_movies = collection.find({'genres': 'Horror'})

for movie in horror_movies:
    pprint.pprint(movie)
# Out:
# Streaming output truncated to the last 5000 lines.
#  'genres': ['Drama', 'Horror', 'Thriller'],
#  'imdb': {'id': 2072134, 'rating': 4.7, 'votes': 533},
#  'languages': ['English'],
#  'lastupdated': '2015-07-26 00:52:35.100000000',
#  'num_mflix_comments': 0,
#  'plot': 'When a father and son become stranded in the wild, they must '
#          'confront the horrors of their past to escape with their lives.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjIyNzkwMTE4N15BMl5BanBnXkFtZTcwODg3Nzk0OA@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2012, 1, 28, 0, 0),
#  'runtime': 81,
#  'title': "It's in the Blood",
#  'tomatoes': {'dvd': datetime.datetime(2013, 4, 23, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 15, 18, 7, 6),
#               'production': 'Gravitas',
#               'viewer': {'meter': 34, 'numReviews': 52, 'rating': 2.6},
#               'website': 'http://www.itsinthebloodthemovie.com/'},
#  'type': 'movie',
#  'writers': ['Scooter Downey', 'Sean Elliot'],
#  'year': 2012}
# {'_id': ObjectId('573a13d6f29313caabd9f5dc'),
#  'awards': {'nominations': 0, 'text': '3 wins.', 'wins': 3},
#  'cast': ['James Davidson',
#           'Sara Anne Jones',
#           'Whitleigh Higuera',
#           'Jamie Siebold'],
#  'countries': ['USA'],
#  'directors': ['Jason Banker'],
#  'fullplot': 'A portrait of contemporary youth culture, where the lines '
#              'between reality and fiction are blurred with often frightening '
#              'results.',
#  'genres': ['Horror', 'Thriller'],
#  'imdb': {'id': 2076372, 'rating': 5.1, 'votes': 750},
#  'languages': ['English'],
#  'lastupdated': '2015-08-28 00:35:36.893000000',
#  'metacritic': 54,
#  'num_mflix_comments': 2,
#  'plot': 'A portrait of contemporary youth culture, where the lines between '
#          'reality and fiction are blurred with often frightening results.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjIyNTc3NDkyN15BMl5BanBnXkFtZTcwNjMwNTA3OA@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2013, 10, 25, 0, 0),
#  'runtime': 76,
#  'title': 'Toad Road',
#  'tomatoes': {'critic': {'meter': 83, 'numReviews': 6, 'rating': 5.6},
#               'dvd': datetime.datetime(2013, 12, 10, 0, 0),
#               'fresh': 5,
#               'lastUpdated': datetime.datetime(2015, 9, 11, 17, 21, 40),
#               'production': 'Artsploitation Films',
#               'rotten': 1,
#               'viewer': {'meter': 44, 'numReviews': 219, 'rating': 2.9},
#               'website': 'http://www.artsploitationfilms.com/toad-road/'},
#  'type': 'movie',
#  'writers': ['Jason Banker'],
#  'year': 2012}
# {'_id': ObjectId('573a13d5f29313caabd9a729'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Samuel Davis',
#           'Roger Edwards',
#           'George P. Gakoumis Jr.',
#           'Dora Madison'],
#  'countries': ['USA'],
#  'directors': ['Eduardo Sènchez'],
#  'fullplot': 'For five friends, it was a chance for a summer getaway- a '
#              'weekend of camping in the Texas Big Thicket. But visions of a '
#              'carefree vacation are shattered with an accident on a dark and '
#              'desolate country road. In the wake of the accident, a '
#              'bloodcurdling force of nature is unleashed-something not exactly '
#              'human, but not completely animal- an urban legend come to '
#              'terrifying life...and seeking murderous revenge.',
#  'genres': ['Horror'],
#  'imdb': {'id': 1988621, 'rating': 5.2, 'votes': 4224},
#  'languages': ['English'],
#  'lastupdated': '2015-08-21 00:15:52',
#  'metacritic': 22,
#  'num_mflix_comments': 3,
#  'plot': 'A group of friends who venture into the remote Texas woods for a '
#          'party weekend find themselves stalked by Bigfoot.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQxNjgzNDQ1M15BMl5BanBnXkFtZTgwNzA1MjE1MjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2014, 10, 3, 0, 0),
#  'runtime': 81,
#  'title': 'Exists',
#  'tomatoes': {'critic': {'meter': 33, 'numReviews': 21, 'rating': 3.7},
#               'dvd': datetime.datetime(2015, 2, 3, 0, 0),
#               'fresh': 7,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 17, 20, 13),
#               'production': 'Lionsgate',
#               'rotten': 14,
#               'viewer': {'meter': 30, 'numReviews': 1560, 'rating': 2.8},
#               'website': 'http://www.facebook.com/existsmovie'},
#  'type': 'movie',
#  'writers': ['Jamie Nash'],
#  'year': 2014}
# {'_id': ObjectId('573a13d7f29313caabda31c8'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Dan Palmer', 'Antonia Bernath', 'Tamaryn Payne', 'Mark Holden'],
#  'countries': ['UK'],
#  'directors': ['Christian James'],
#  'fullplot': "A janitor gets trapped in a women's restroom and encounters an "
#              'all-out attack by a horde of zombies.',
#  'genres': ['Comedy', 'Horror'],
#  'imdb': {'id': 2140429, 'rating': 4.7, 'votes': 1189},
#  'languages': ['English'],
#  'lastupdated': '2015-08-18 00:58:57.797000000',
#  'num_mflix_comments': 1,
#  'plot': "A janitor gets trapped in a women's restroom and encounters an "
#          'all-out attack by a horde of zombies.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTM5MTQ4ODE2NV5BMl5BanBnXkFtZTgwNTgwNTQyMDE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 3, 25, 0, 0),
#  'runtime': 84,
#  'title': 'Stalled',
#  'tomatoes': {'dvd': datetime.datetime(2014, 3, 3, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 7, 27, 19, 15, 58),
#               'production': "Uncork'd Entertainment",
#               'viewer': {'meter': 29, 'numReviews': 101, 'rating': 2.6},
#               'website': 'http://www.phase4films.com/'},
#  'type': 'movie',
#  'writers': ['Dan Palmer (screenplay)'],
#  'year': 2013}
# {'_id': ObjectId('573a13d7f29313caabda3782'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Iain P.F. McDonald', 'Kate Henderson', 'Steve Lynch', 'Libby Ashby'],
#  'countries': ['Australia'],
#  'directors': ['Tanzeal Rahim'],
#  'fullplot': 'In 2007 author Phillip Muirhouse was left alone in a haunted '
#              "homestead called 'Monte Cristo'. He was there making a "
#              'documentary that was to accompany his latest book. He also broke '
#              'the rule of all ghost hunters.... Never Be Alone. The following '
#              'is video documentation leading to he is arrest.',
#  'genres': ['Drama', 'Horror', 'Thriller'],
#  'imdb': {'id': 2146834, 'rating': 4.5, 'votes': 294},
#  'languages': ['English'],
#  'lastupdated': '2015-08-02 00:42:42.717000000',
#  'num_mflix_comments': 0,
#  'plot': 'In 2007 author Phillip Muirhouse was left alone in a haunted '
#          "homestead called 'Monte Cristo'. He was there making a documentary "
#          'that was to accompany his latest book. He also broke the rule...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjE4MTM1MTIyMl5BMl5BanBnXkFtZTcwMjI3MTExOA@@._V1_SY1000_SX677_AL_.jpg',
#  'runtime': 75,
#  'title': 'Muirhouse',
#  'type': 'movie',
#  'writers': ['Tanzeal Rahim'],
#  'year': 2012}
# {'_id': ObjectId('573a13d8f29313caabda5f31'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Ciara Hanna',
#           "Emily O'Brien",
#           'Jackie Moore',
#           'Russell Geoffrey Banks'],
#  'countries': ['USA', 'Thailand'],
#  'directors': ['James Cullen Bressack'],
#  'fullplot': 'Three young, beautiful girls arrive in Thailand to teach English '
#              'for the summer, some with noble intentions and some just wanting '
#              'an adventure, but none were prepared for the massacre that '
#              'awaited them. The nightmare begins when their new friends go '
#              'missing, vivid bloody dreams haunt their sleep and a stolen '
#              'statue leads them down a dark path into Thai folklore and magic '
#              'that has been long forgotten. Their situation continues to '
#              "become worse once they realize it's not WHAT that is haunting "
#              'them but WHO: an eight-year girl, brutally murdered and '
#              'sacrificed by her family decades ago who wants nothing more than '
#              'to watch them bleed. This is not a story about redemption. This '
#              'is not a story about good versus evil. This is not a story about '
#              'the will to survive. This is a story about Vanida - a child '
#              'viciously tortured by her own family, who will stop at nothing '
#              'for revenge - one appendage at a time.',
#  'genres': ['Horror', 'Thriller'],
#  'imdb': {'id': 2187444, 'rating': 5.8, 'votes': 1630},
#  'languages': ['English'],
#  'lastupdated': '2015-09-06 00:12:33.883000000',
#  'num_mflix_comments': 1,
#  'plot': 'It was supposed to be an adventure of a lifetime as three young '
#          'girls spend the summer in Thailand. But their adventure quickly '
#          'becomes a nightmare when the trio unleashes the spirit of a murdered '
#          'child with only one thing on her mind - revenge.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYTFhZWM2MzYtZGQyZi00MGQ3LTllZjctNTk4YzU2YTM3ZjAxXkEyXkFqcGdeQXVyMjUxOTAxNzI@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 2, 20, 0, 0),
#  'runtime': 90,
#  'title': 'Pernicious',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 12, 19, 32, 38),
#               'production': 'Benetone Films',
#               'viewer': {'meter': 92, 'numReviews': 292, 'rating': 4.8},
#               'website': 'http://www.perniciousmovie.com/'},
#  'type': 'movie',
#  'writers': ['James Cullen Bressack (story)',
#              'James Cullen Bressack',
#              'Taryn Hillin'],
#  'year': 2014}
# {'_id': ObjectId('573a13d5f29313caabd9a862'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Devon Bostick',
#           'Martha MacIsaac',
#           'Christopher Lloyd',
#           'Brandon Jay McLaren'],
#  'countries': ['Canada'],
#  'directors': ['April Mullen'],
#  'fullplot': 'A group of college kids accidentally create, and then unleash, a '
#              'curse that makes anyone they come into contact with kill '
#              'themselves and then turn into zombie demons.',
#  'genres': ['Adventure', 'Comedy', 'Horror'],
#  'imdb': {'id': 1989485, 'rating': 4.9, 'votes': 2807},
#  'languages': ['English'],
#  'lastupdated': '2015-08-29 00:05:08.140000000',
#  'num_mflix_comments': 0,
#  'plot': 'A group of college kids accidentally create, and then unleash, a '
#          'curse that makes anyone they come into contact with kill themselves '
#          'and then turn into zombie demons.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2ODIyNTU1OF5BMl5BanBnXkFtZTcwOTM1MTI2OQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2012, 10, 11, 0, 0),
#  'runtime': 88,
#  'title': 'Dead Before Dawn 3D',
#  'tomatoes': {'dvd': datetime.datetime(2013, 8, 21, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 18, 18, 58, 15),
#               'production': 'Gaiam Vivendi Entertainment',
#               'viewer': {'meter': 26, 'numReviews': 337, 'rating': 2.6},
#               'website': 'http://deadbeforedawnthemovie.com/'},
#  'type': 'movie',
#  'writers': ['Tim Doiron'],
#  'year': 2012}
# {'_id': ObjectId('573a13d5f29313caabd9ab83'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Ingrid Bolsè Berdal',
#           'Dimitri Diatchenko',
#           'Olivia Taylor Dudley',
#           'Devin Kelley'],
#  'countries': ['USA'],
#  'directors': ['Bradley Parker'],
#  'fullplot': 'Americans Chris, his girlfriend Natalie and their friend Amanda '
#              "travel to Europe on vacation. They meet up with Chris' brother "
#              'Paul living in Kiev, Ukraine. Chris wants to travel to Moscow to '
#              'propose to Natalie, but Paul convinces the group to first visit '
#              'Chernobyl with an extreme tourism guide. They meet the guide Uri '
#              'and another couple who are also going on the tour. Uri explains '
#              'that because of the radiation levels he can only take them to '
#              'Pripyat, a deserted city very near Chernobyl. They travel by '
#              'van, but are stopped by a military checkpoint that makes them '
#              'turn back. Not giving up, Uri finds an alternative route to the '
#              'town. The group spends the day taking photographs and exploring '
#              "abandoned buildings. Uri becomes nervous and decides it's time "
#              "to head home. However, the van won't start and they discover the "
#              'engine was sabotaged. Soon they discover that they are stranded, '
#              'no one knows they are there and that they are definitely not '
#              'alone.',
#  'genres': ['Horror', 'Mystery', 'Thriller'],
#  'imdb': {'id': 1991245, 'rating': 5.0, 'votes': 49660},
#  'languages': ['English'],
#  'lastupdated': '2015-09-13 00:34:28.350000000',
#  'num_mflix_comments': 0,
#  'plot': 'Six tourists hire an extreme tour guide who takes them to the '
#          'abandoned city Pripyat, the former home to the workers of the '
#          'Chernobyl nuclear reactor. During their exploration, they soon '
#          'discover they are not alone.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNzkwNDkyNTUxNV5BMl5BanBnXkFtZTcwODY1NTE3Nw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2012, 5, 25, 0, 0),
#  'runtime': 86,
#  'title': 'Chernobyl Diaries',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 15, 18, 3, 28),
#               'viewer': {'numReviews': 25, 'rating': 3.8}},
#  'type': 'movie',
#  'writers': ['Oren Peli (screenplay)',
#              'Carey Van Dyke (screenplay)',
#              'Shane Van Dyke (screenplay)',
#              'Oren Peli (story)'],
#  'year': 2012}
# {'_id': ObjectId('573a13d7f29313caabda14b0'),
#  'awards': {'nominations': 4, 'text': '4 nominations.', 'wins': 0},
#  'cast': ['Calvin Reeder', 'Lane Hughes', 'Kentucker Audley', 'Adam Wingard'],
#  'countries': ['USA'],
#  'directors': ['Matt Bettinelli-Olpin',
#                'David Bruckner',
#                'Tyler Gillett',
#                'Justin Martinez',
#                'Glenn McQuaid',
#                'Radio Silence',
#                'Joe Swanberg',
#                'Chad Villella',
#                'Ti West',
#                'Adam Wingard'],
#  'fullplot': 'A POV, found footage horror film from the perspective of '
#              "America's top genre filmmakers. A group of misfits are hired by "
#              'an unknown third party to burglarize a desolate house in the '
#              'countryside and acquire a rare tape. Upon searching the house, '
#              'the guys are confronted with a dead body, a hub of old '
#              'televisions and an endless supply of cryptic footage, each video '
#              'stranger than the last.',
#  'genres': ['Horror', 'Thriller'],
#  'imdb': {'id': 2105044, 'rating': 5.8, 'votes': 39392},
#  'languages': ['English'],
#  'lastupdated': '2015-09-14 07:55:43.460000000',
#  'metacritic': 55,
#  'num_mflix_comments': 0,
#  'plot': 'When a group of misfits is hired by an unknown third party to '
#          'burglarize a desolate house and acquire a rare VHS tape, they '
#          'discover more found footage than they bargained for.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTUwODAxMzMwNF5BMl5BanBnXkFtZTcwMTk3MTQ5Nw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2012, 9, 6, 0, 0),
#  'runtime': 116,
#  'title': 'V/H/S',
#  'tomatoes': {'boxOffice': '$99.8k',
#               'consensus': 'An uneven collection of found-footage horror '
#                            'films, V/H/S has some inventive scares but its '
#                            'execution is hit-and-miss.',
#               'critic': {'meter': 55, 'numReviews': 93, 'rating': 5.6},
#               'dvd': datetime.datetime(2012, 12, 4, 0, 0),
#               'fresh': 51,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 17, 46, 30),
#               'production': 'Magnolia Pictures',
#               'rotten': 42,
#               'viewer': {'meter': 41, 'numReviews': 15098, 'rating': 2.9},
#               'website': 'http://www.facebook.com/VHSfilm'},
#  'type': 'movie',
#  'writers': ['Brad Miska (concept)',
#              'Simon Barrett',
#              'David Bruckner',
#              'Nicholas Tecosky',
#              'Ti West',
#              'Glenn McQuaid',
#              'Simon Barrett',
#              'Radio Silence',
#              'Matt Bettinelli-Olpin',
#              'Tyler Gillett',
#              'Justin Martinez',
#              'Chad Villella'],
#  'year': 2012}
# {'_id': ObjectId('573a13d8f29313caabda5c08'),
#  'awards': {'nominations': 6, 'text': '1 win & 6 nominations.', 'wins': 1},
#  'cast': ['Ethan Hawke', 'Lena Headey', 'Max Burkholder', 'Adelaide Kane'],
#  'countries': ['USA', 'France'],
#  'directors': ['James DeMonaco'],
#  'fullplot': 'In an America wracked by crime and overcrowded prisons, the '
#              'government has sanctioned an annual 12-hour period in which any '
#              'and all criminal activity-including murder-becomes legal. The '
#              "police can't be called. Hospitals suspend help. It's one night "
#              'when the citizenry regulates itself without thought of '
#              'punishment. On this night plagued by violence and an epidemic of '
#              'crime, one family wrestles with the decision of who they will '
#              'become when a stranger comes knocking. When an intruder breaks '
#              "into James Sandin's (Ethan Hawke) gated community during the "
#              'yearly lockdown, he begins a sequence of events that threatens '
#              'to tear a family apart. Now, it is up to James, his wife, Mary '
#              '(Lena Headey), and their kids to make it through the night '
#              'without turning into the monsters from whom they hide.',
#  'genres': ['Horror', 'Sci-Fi', 'Thriller'],
#  'imdb': {'id': 2184339, 'rating': 5.6, 'votes': 118028},
#  'languages': ['English'],
#  'lastupdated': '2015-09-12 00:20:47.107000000',
#  'metacritic': 41,
#  'num_mflix_comments': 0,
#  'plot': 'In the future, a wealthy family is held hostage for harboring the '
#          'target of a murderous syndicate during the Purge, a 12-hour period '
#          'in which any and all crime is legalized.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQzNTcwODEyM15BMl5BanBnXkFtZTcwMjM1MDI0OQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2013, 6, 7, 0, 0),
#  'runtime': 85,
#  'title': 'The Purge',
#  'tomatoes': {'boxOffice': '$64.4M',
#               'consensus': 'Half social allegory, half home-invasion thriller, '
#                            'The Purge attempts to make an intelligent point, '
#                            'but ultimately devolves into numbing violence and '
#                            'tired clichès.',
#               'critic': {'meter': 38, 'numReviews': 137, 'rating': 5.1},
#               'dvd': datetime.datetime(2013, 10, 8, 0, 0),
#               'fresh': 52,
#               'lastUpdated': datetime.datetime(2015, 8, 25, 18, 1, 26),
#               'production': 'Universal Pictures',
#               'rotten': 85,
#               'viewer': {'meter': 36, 'numReviews': 94008, 'rating': 2.9},
#               'website': 'http://www.facebook.com/thepurgemovie'},
#  'type': 'movie',
#  'writers': ['James DeMonaco'],
#  'year': 2013}
# {'_id': ObjectId('573a13d8f29313caabda56fb'),
#  'awards': {'nominations': 0, 'text': '4 wins.', 'wins': 4},
#  'cast': ['Sam Scarber', 'Dahlia Salem', 'David Banks', 'David Rountree'],
#  'countries': ['USA'],
#  'directors': ['David Rountree'],
#  'fullplot': 'Nothing is as it seems as an ex-con and aspirant filmmaker set '
#              'out to manufacture a horror film by scaring real people; '
#              'however, when it goes too far and someone actually dies, the '
#              'pair decide that killing for real on film is the way to make a '
#              'truly terrifying movie.',
#  'genres': ['Horror', 'Mystery', 'Thriller'],
#  'imdb': {'id': 2179007, 'rating': 6.4, 'votes': 1132},
#  'languages': ['English'],
#  'lastupdated': '2015-08-20 01:02:17.080000000',
#  'num_mflix_comments': 1,
#  'plot': 'Nothing is as it seems as an ex-con and aspirant filmmaker set out '
#          'to manufacture a horror film by scaring real people; however, when '
#          'it goes too far and someone actually dies, the pair ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTM3MjI1NTE1Nl5BMl5BanBnXkFtZTcwOTIyMjIzOA@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 2, 1, 0, 0),
#  'runtime': 101,
#  'title': 'Cut!',
#  'tomatoes': {'dvd': datetime.datetime(2015, 2, 24, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 7, 20, 9, 22),
#               'production': 'Psycho Rock Productions',
#               'viewer': {'meter': 67, 'numReviews': 78, 'rating': 3.9},
#               'website': 'http://www.thecutmovie.com/'},
#  'type': 'movie',
#  'writers': ['David Banks', 'David Rountree'],
#  'year': 2014}
# {'_id': ObjectId('573a13d5f29313caabd9be43'),
#  'awards': {'nominations': 1, 'text': '2 wins & 1 nomination.', 'wins': 2},
#  'cast': ['Marta Milans', 'Kara Jackson', 'Bruno Gunn', 'Tyler Hollinger'],
#  'countries': ['USA'],
#  'directors': ['Greg Olliver'],
#  'fullplot': 'Lourdes is a young woman that works at night cleaning a '
#              'restaurant. All the money she made is for her son that lives in '
#              'her hometown with her mother. We know very little about Lourdes '
#              'son, only that he is sick and Lourdes is working every night and '
#              'sending money to help her son and find a cure for his illness. '
#              'Suddenly, Lourdes starts seeing visions in the restaurant where '
#              'she works, in her little apartment. These visions, her evil '
#              'co-workers and her son apart from her, all this stress Lourdes '
#              'out and she began questioning herself who wants to hurt her? Or '
#              'if all of whats happening is really happening or not.',
#  'genres': ['Drama', 'Horror', 'Thriller'],
#  'imdb': {'id': 2010976, 'rating': 5.4, 'votes': 955},
#  'languages': ['English', 'Spanish'],
#  'lastupdated': '2015-08-25 01:01:21.977000000',
#  'num_mflix_comments': 0,
#  'plot': 'Lourdes is a young woman that works at night cleaning a restaurant. '
#          'All the money she made is for her son that lives in her hometown '
#          'with her mother. We know very little about Lourdes son, ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNjA3OTM0OTgxMl5BMl5BanBnXkFtZTgwNzg3ODU4NzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 9, 2, 0, 0),
#  'runtime': 89,
#  'title': 'Devoured',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 13, 17, 55, 19),
#               'production': 'Gravitas Ventures',
#               'viewer': {'meter': 38, 'numReviews': 122, 'rating': 2.8}},
#  'type': 'movie',
#  'writers': ['Marc Landau'],
#  'year': 2012}
# {'_id': ObjectId('573a13d5f29313caabd9d5fc'),
#  'awards': {'nominations': 2, 'text': '2 nominations.', 'wins': 0},
#  'cast': ['Caity Lotz', 'Kathleen Rose Perkins', 'Haley Hudson', 'Sam Ball'],
#  'countries': ['USA'],
#  'directors': ['Nicholas McCarthy'],
#  'fullplot': 'Nichole Barlow comes to San Pedro with her daughter Eva to '
#              'attend the funeral of her mother. She calls her estranged sister '
#              'Annie to help her to resolve pending businesses, but Annie is '
#              'too traumatized with the bad treatment spent by their mother and '
#              'does not want to return to their childhood home. Nichole '
#              'convinces her sister to come and she arrives to the funeral. '
#              "However, Nichole goes missing and Eva stays with Nichole's "
#              'cousin Liz. When Liz also disappears, Annie claims that '
#              'supernatural events happen in the house but she becomes the '
#              'prime-suspect. The open-minded detective Bill Creek assumes the '
#              'investigation and realizes that there is something weird in the '
#              'house. Meanwhile Annie summons the medium Stevie believing that '
#              'the ghost of her mother is responsible for the vanishing of '
#              'Nichole and Liz. But the woman warns Annie that there is a great '
#              'danger in the house. Annie decides to go further in her '
#              'investigation and discovers dark secrets from the past of her '
#              'family.',
#  'genres': ['Horror', 'Mystery', 'Thriller'],
#  'imdb': {'id': 2040560, 'rating': 5.8, 'votes': 17727},
#  'languages': ['English'],
#  'lastupdated': '2015-09-15 05:38:44.637000000',
#  'metacritic': 54,
#  'num_mflix_comments': 1,
#  'plot': 'As a woman struggles to come to grips with her past in the wake of '
#          "her mother's death and the disappearance of her sister, an "
#          'unsettling presence emerges in her childhood home.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTU1NDI4ODA4N15BMl5BanBnXkFtZTcwNDMyMzk4Nw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2012, 6, 8, 0, 0),
#  'runtime': 89,
#  'title': 'The Pact',
#  'tomatoes': {'critic': {'meter': 67, 'numReviews': 33, 'rating': 5.7},
#               'dvd': datetime.datetime(2012, 11, 6, 0, 0),
#               'fresh': 22,
#               'lastUpdated': datetime.datetime(2015, 8, 17, 18, 10, 58),
#               'production': 'IFC Films',
#               'rotten': 11,
#               'viewer': {'meter': 41, 'numReviews': 9680, 'rating': 3.0},
#               'website': 'http://www.ifcfilms.com/films/the-pact'},
#  'type': 'movie',
#  'writers': ['Nicholas McCarthy'],
#  'year': 2012}
# {'_id': ObjectId('573a13d7f29313caabda4a63'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Robert Englund',
#           'Fiona Dourif',
#           'Felisha Terrell',
#           'Cleopatra Coleman'],
#  'countries': ['USA'],
#  'directors': ['Robert Hall'],
#  'fullplot': 'A doctor works to cure patients suffering from crippling phobias '
#              'by placing them inside his invention which induces and controls '
#              'hallucinations.',
#  'genres': ['Horror'],
#  'imdb': {'id': 2165765, 'rating': 5.6, 'votes': 5946},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:05:08.780000000',
#  'num_mflix_comments': 0,
#  'plot': 'A doctor works to cure patients suffering from crippling phobias by '
#          'placing them inside his invention which induces and controls '
#          'hallucinations.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2NjA5MTA3NF5BMl5BanBnXkFtZTgwNDk1MDExMzE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 1, 30, 0, 0),
#  'runtime': 95,
#  'title': 'Fear Clinic',
#  'tomatoes': {'dvd': datetime.datetime(2015, 2, 10, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 20, 18, 7, 36),
#               'production': 'Anchor Bay Entertainment',
#               'viewer': {'meter': 19, 'numReviews': 173, 'rating': 2.3},
#               'website': 'http://fearclinicmovie.com/'},
#  'type': 'movie',
#  'writers': ['Aaron Drane', 'Robert Hall'],
#  'year': 2014}
# {'_id': ObjectId('573a13d7f29313caabda4a87'),
#  'awards': {'nominations': 2, 'text': '2 nominations.', 'wins': 0},
#  'cast': ['Iain De Caestecker', 'Alice Englert', 'Allen Leech'],
#  'countries': ['UK'],
#  'directors': ['Jeremy Lovering'],
#  'fullplot': 'Tom and Lucy are both happy young adults eager to set out on '
#              'their first weekend getaway as a couple. They set off for a '
#              'planned stay at a remote hotel but quickly find themselves '
#              'getting lost in a maze of backwoods roads. However they soon '
#              'discover that they are at the mercies of an unknown tormentor '
#              'that is eager to take advantage of their vulnerability and '
#              'distance from civilization.',
#  'genres': ['Horror', 'Mystery', 'Thriller'],
#  'imdb': {'id': 2165859, 'rating': 5.5, 'votes': 5355},
#  'languages': ['English'],
#  'lastupdated': '2015-09-05 00:29:04.970000000',
#  'metacritic': 66,
#  'num_mflix_comments': 1,
#  'plot': 'Driving to a music festival in Ireland, a new couple become lost and '
#          'are then set upon by a tormentor with an unknown motive.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTc3MzQ5NTA3OV5BMl5BanBnXkFtZTgwNjI4MTYwMTE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2013, 11, 15, 0, 0),
#  'runtime': 85,
#  'title': 'In Fear',
#  'tomatoes': {'consensus': 'Compact and effective, In Fear offers discerning '
#                            'horror fans a smart and disturbing plunge into the '
#                            'depths of cinematic anxiety.',
#               'critic': {'meter': 83, 'numReviews': 52, 'rating': 6.8},
#               'dvd': datetime.datetime(2014, 3, 11, 0, 0),
#               'fresh': 43,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 19, 40, 16),
#               'production': 'Anchor Bay/Freestyle Releasing',
#               'rotten': 9,
#               'viewer': {'meter': 41, 'numReviews': 8368, 'rating': 2.9}},
#  'type': 'movie',
#  'writers': ['Jeremy Lovering'],
#  'year': 2013}
# {'_id': ObjectId('573a13d8f29313caabda571a'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Mischa Barton', 'Ryan Eggold', 'Leah Pipes', 'Frank Ashmore'],
#  'countries': ['USA'],
#  'directors': ['Mark Edwin Robinson'],
#  'fullplot': 'Story follows Sophia, who is severely depressed after the deaths '
#              'of both her parents within six months. Convinced that the '
#              'Afterlife is mere oblivion, and that this life is meaningless, '
#              'she retreats within herself, only to be drawn out of her '
#              'depressive funk by an unexpected romance with a man named Adam. '
#              'After Adam disappears mysteriously into the depths of a haunted '
#              'apartment building, Sophia vows to pursue him, even if it means '
#              'walking over the threshold into the realm of death.',
#  'genres': ['Drama', 'Horror', 'Romance'],
#  'imdb': {'id': 2179087, 'rating': 4.5, 'votes': 898},
#  'languages': ['English'],
#  'lastupdated': '2015-08-28 00:18:02.627000000',
#  'metacritic': 12,
#  'num_mflix_comments': 1,
#  'plot': 'A woman reeling from the death of her parents becomes attached to an '
#          'alluring man whose sudden disappearance sends her and her friends '
#          'into a haunted high-rise to find him',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQzNzY1MzU5MV5BMl5BanBnXkFtZTgwODQ5MTIzMDE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2013, 10, 11, 0, 0),
#  'runtime': 112,
#  'title': 'I Will Follow You Into the Dark',
#  'tomatoes': {'critic': {'meter': 11, 'numReviews': 9, 'rating': 2.6},
#               'dvd': datetime.datetime(2014, 1, 27, 0, 0),
#               'fresh': 1,
#               'lastUpdated': datetime.datetime(2015, 8, 17, 19, 28, 26),
#               'production': 'Epic Pictures Releasing',
#               'rotten': 8,
#               'viewer': {'meter': 24, 'numReviews': 167, 'rating': 2.5}},
#  'type': 'movie',
#  'writers': ['Mark Edwin Robinson'],
#  'year': 2012}
# {'_id': ObjectId('573a13d9f29313caabda8725'),
#  'awards': {'nominations': 1, 'text': '2 wins & 1 nomination.', 'wins': 2},
#  'cast': ['Anta Aizupe', 'Maxim Lazarev', 'Aris Rozentals'],
#  'countries': ['Latvia', 'Estonia'],
#  'directors': ['Aik Karapetian'],
#  'genres': ['Horror', 'Mystery', 'Thriller'],
#  'imdb': {'id': 2231646, 'rating': 5.5, 'votes': 167},
#  'languages': ['Latvian'],
#  'lastupdated': '2015-08-08 00:22:42.570000000',
#  'num_mflix_comments': 0,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTU3OTc3NjMzN15BMl5BanBnXkFtZTgwNzI4OTY2MjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 2, 27, 0, 0),
#  'runtime': 71,
#  'title': 'The Man in the Orange Jacket',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 4, 19, 18, 34),
#               'viewer': {'numReviews': 3, 'rating': 5.0}},
#  'type': 'movie',
#  'writers': ['Aik Karapetian'],
#  'year': 2014}
# {'_id': ObjectId('573a13d9f29313caabdaaec9'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Holly Goss', 'Matt Stokoe', 'Luke Albright', 'Ryan Hawley'],
#  'countries': ['USA', 'UK', 'Russia'],
#  'directors': ['Renny Harlin'],
#  'fullplot': 'The Dyatlov Pass follows a group of American students on a trek '
#              'to investigate the true life mystery of nine Russian skiers who '
#              'befell unexplained deaths while skiing in the Russian mountains '
#              'in 1959. To this day, their deaths have been one of the most '
#              'bizarre unsolved mysteries of the 20th century.',
#  'genres': ['Horror', 'Mystery', 'Sci-Fi'],
#  'imdb': {'id': 1905040, 'rating': 5.7, 'votes': 12987},
#  'languages': ['English', 'Russian'],
#  'lastupdated': '2015-09-03 01:58:44.240000000',
#  'metacritic': 49,
#  'num_mflix_comments': 2,
#  'plot': 'Five young filmmakers retrace the steps of a doomed group of hikers '
#          'in pursuit of an unsolvable mystery.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjMzOTMxMTA3N15BMl5BanBnXkFtZTgwNDg4MDAwMDE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2013, 2, 28, 0, 0),
#  'runtime': 100,
#  'title': "Devil's Pass",
#  'tomatoes': {'critic': {'meter': 53, 'numReviews': 19, 'rating': 4.9},
#               'dvd': datetime.datetime(2013, 12, 16, 0, 0),
#               'fresh': 10,
#               'lastUpdated': datetime.datetime(2015, 9, 17, 17, 31, 3),
#               'production': 'DPI Productions LLC.',
#               'rotten': 9,
#               'viewer': {'meter': 29, 'numReviews': 1123, 'rating': 2.8},
#               'website': 'http://www.ifcfilms.com/uncategorized/devilspass'},
#  'type': 'movie',
#  'writers': ['Vikram Weet'],
#  'year': 2013}
# {'_id': ObjectId('573a13dcf29313caabdb1c23'),
#  'awards': {'nominations': 8, 'text': '3 wins & 8 nominations.', 'wins': 3},
#  'cast': ['Joe Swanberg', 'AJ Bowen', 'Kentucker Audley', 'Gene Jones'],
#  'countries': ['USA'],
#  'directors': ['Ti West'],
#  'fullplot': 'The journalist Patrick works at the VICE, a company dedicated to '
#              'cover bizarre news. When his sister Caroline joins a community, '
#              'she travels abroad with her new family. Out of the blue, '
#              'Caroline invites her brother to visit her in an undefined '
#              'country and Patrick travels by helicopter with his friends Jake '
#              'and Sam that work with him at VICE. They find weird that the men '
#              'that have come to guide them to the Eden Parish have guns. On '
#              'the arrival to the camp, Patrick, Sam and Jake find a community '
#              'of happy people that worship Father. They interview Father but '
#              'soon they realize that people are not as happy as they seem to '
#              'be. Further, they find that they are trapped in the Parish Eden '
#              'and they want to leave the place with the newcomers. But the '
#              'Father does not have intention to let them go.',
#  'genres': ['Horror', 'Thriller'],
#  'imdb': {'id': 2383068, 'rating': 6.1, 'votes': 9205},
#  'languages': ['English'],
#  'lastupdated': '2015-09-11 00:30:22.177000000',
#  'metacritic': 49,
#  'num_mflix_comments': 0,
#  'plot': 'A news team trails a man as he travels into the world of Eden Parish '
#          'to find his missing sister, where it becomes apparent that this '
#          'paradise may not be as it seems.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjE1ODg1MzM3Ml5BMl5BanBnXkFtZTgwMDg3NDQyMTE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2014, 5, 1, 0, 0),
#  'runtime': 99,
#  'title': 'The Sacrament',
#  'tomatoes': {'boxOffice': '$9.0k',
#               'consensus': 'While it may be a bit too slow for some, The '
#                            'Sacrament offers enough tense atmosphere and '
#                            'intriguing ideas to satisfy discerning horror '
#                            'buffs.',
#               'critic': {'meter': 62, 'numReviews': 60, 'rating': 5.7},
#               'dvd': datetime.datetime(2014, 8, 19, 0, 0),
#               'fresh': 37,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 18, 24, 43),
#               'production': 'Magnet Releasing',
#               'rotten': 23,
#               'viewer': {'meter': 47, 'numReviews': 4057, 'rating': 3.2},
#               'website': 'http://www.thesacramentmovie.com'},
#  'type': 'movie',
#  'writers': ['Ti West'],
#  'year': 2013}
# {'_id': ObjectId('573a13dbf29313caabdafb40'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Tao Guo', 'Barbie Hsu', 'Suet Lam'],
#  'countries': ['China'],
#  'directors': ['Li Sheng Lin'],
#  'fullplot': 'Xiao, befriends Amao a 36 foot crocodile, who lives on his '
#              "fathers croc sanctuary. Xiao's father is forced to sell his "
#              'crocodiles to a gangster who plans to use them for high priced '
#              'meals. Before Amao is due to be slaughtered, he escapes, slaying '
#              'his captors in the process. Amongst the chaos, Amao accidentally '
#              "swallows a bag with $1 million dollars inside. When rumor's of "
#              'this spread, the town locals are split with some fearing for '
#              'their lives and others set out to capture and kill the '
#              'crocodile, at any cost.',
#  'genres': ['Action', 'Comedy', 'Horror'],
#  'imdb': {'id': 2354196, 'rating': 4.1, 'votes': 423},
#  'lastupdated': '2015-08-24 00:17:12.917000000',
#  'num_mflix_comments': 0,
#  'plot': 'A 36 foot crocodile goes on the rampage in Beijing after being moved '
#          'from a peaceful Crocodile Farm and onto the menu of a local '
#          'gangster.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQxMjExNjU5Ml5BMl5BanBnXkFtZTgwMjg3MjIwMDE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2012, 6, 8, 0, 0),
#  'runtime': 90,
#  'title': 'Croczilla',
#  'tomatoes': {'dvd': datetime.datetime(2013, 2, 12, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 31, 18, 52, 24),
#               'viewer': {'meter': 17, 'numReviews': 27, 'rating': 2.0}},
#  'type': 'movie',
#  'writers': ['Li Sheng Lin'],
#  'year': 2012}
# {'_id': ObjectId('573a13daf29313caabdacefc'),
#  'awards': {'nominations': 9, 'text': '7 wins & 9 nominations.', 'wins': 7},
#  'cast': ['Kassie Wesley DePaiva',
#           'Laurent Rejto',
#           'Julia Garner',
#           'Ambyr Childers'],
#  'countries': ['USA', 'France'],
#  'directors': ['Jim Mickle'],
#  'fullplot': 'A seemingly wholesome and benevolent family, the Parkers have '
#              'always kept to themselves, and for good reason. Behind closed '
#              'doors, patriarch Frank rules his family with a rigorous fervor, '
#              'determined to keep his ancestral customs intact at any cost. As '
#              'a torrential rainstorm moves into the area, tragedy strikes and '
#              'his daughters Iris and Rose are forced to assume '
#              'responsibilities that extend beyond those of a typical family. '
#              'As the unrelenting downpour continues to flood their small town, '
#              'the local authorities begin to uncover clues that bring them '
#              'closer to the secret that the Parkers have held closely for so '
#              'many years.',
#  'genres': ['Drama', 'Horror', 'Thriller'],
#  'imdb': {'id': 2309021, 'rating': 5.8, 'votes': 12891},
#  'languages': ['English'],
#  'lastupdated': '2015-09-01 00:54:27.193000000',
#  'metacritic': 71,
#  'num_mflix_comments': 1,
#  'plot': 'The Parkers, a reclusive family who follow ancient customs, find '
#          'their secret existence threatened as a torrential downpour moves '
#          'into their area, forcing daughters Iris and Rose to assume '
#          'responsibilities beyond those of a typical family.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjI3NjI3NjAyN15BMl5BanBnXkFtZTgwODE3NzMxMDE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2013, 10, 25, 0, 0),
#  'runtime': 105,
#  'title': 'We Are What We Are',
#  'tomatoes': {'consensus': 'A compelling story cleverly told, We Are What We '
#                            "Are quenches horror buffs' thirst for gore while "
#                            'serving up serious-minded filmmaking and solid '
#                            'acting.',
#               'critic': {'meter': 85, 'numReviews': 82, 'rating': 7.0},
#               'dvd': datetime.datetime(2014, 1, 7, 0, 0),
#               'fresh': 70,
#               'lastUpdated': datetime.datetime(2015, 9, 11, 18, 18, 45),
#               'production': 'Entertainment One',
#               'rotten': 12,
#               'viewer': {'meter': 48, 'numReviews': 10069, 'rating': 3.1},
#               'website': 'http://parkerfamilytradition.com/'},
#  'type': 'movie',
#  'writers': ['Nick Damici', 'Jim Mickle', 'Jorge Michel Grau (screenplay)'],
#  'year': 2013}
# {'_id': ObjectId('573a13dcf29313caabdb1aa8'),
#  'awards': {'nominations': 2, 'text': '2 nominations.', 'wins': 0},
#  'cast': ['Dermot Mulroney',
#           'Lindsay Pulsipher',
#           'Natasha Lyonne',
#           'James Cady'],
#  'countries': ['USA'],
#  'directors': ['Calvin Reeder'],
#  'fullplot': 'A quiet drifter leaves prison, finds home on the road.',
#  'genres': ['Comedy', 'Drama', 'Horror'],
#  'imdb': {'id': 2381355, 'rating': 4.6, 'votes': 703},
#  'languages': ['English'],
#  'lastupdated': '2015-09-07 01:02:34.710000000',
#  'metacritic': 32,
#  'num_mflix_comments': 0,
#  'plot': 'A quiet drifter leaves prison, finds home on the road.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTk3OTczMzg1NV5BMl5BanBnXkFtZTcwMTM2ODM3OQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2013, 1, 21, 0, 0),
#  'runtime': 97,
#  'title': 'The Rambler',
#  'tomatoes': {'critic': {'meter': 40, 'numReviews': 10, 'rating': 6.1},
#               'dvd': datetime.datetime(2013, 6, 25, 0, 0),
#               'fresh': 4,
#               'lastUpdated': datetime.datetime(2015, 8, 31, 18, 17, 59),
#               'production': 'Anchor Bay Films',
#               'rotten': 6,
#               'viewer': {'meter': 36, 'numReviews': 159, 'rating': 2.5}},
#  'type': 'movie',
#  'writers': ['Calvin Reeder'],
#  'year': 2013}
# {'_id': ObjectId('573a13daf29313caabdacfe6'),
#  'awards': {'nominations': 6, 'text': '5 wins & 6 nominations.', 'wins': 5},
#  'cast': ['Derek Lee', 'Clif Prowse', 'Michael Gill', 'Baya Rehaz'],
#  'countries': ['Canada', 'USA'],
#  'directors': ['Derek Lee', 'Clif Prowse'],
#  'fullplot': 'Best friends Derek and Clif set out on a trip of lifetime. Their '
#              'plan: travel to the ends of the earth, see the world, and live '
#              'life to the fullest. But the trip soon takes a dark and bloody '
#              'turn. Just days in, one of the men shows signs of a mysterious '
#              'affliction which gradually takes over his entire body and being. '
#              'Now, thousands of miles from home, in a foreign land, they must '
#              'race to uncover the source before it consumes him completely. '
#              'Footage meant to be travel memories may now become evidence of '
#              'one of the most shocking discoveries ever captured on film...and '
#              'perhaps will be their only postcard home.',
#  'genres': ['Action', 'Adventure', 'Horror'],
#  'imdb': {'id': 2309961, 'rating': 6.3, 'votes': 14152},
#  'languages': ['English', 'French', 'Italian'],
#  'lastupdated': '2015-09-10 17:12:49.553000000',
#  'metacritic': 56,
#  'num_mflix_comments': 0,
#  'plot': 'Two best friends see their trip of a lifetime take a dark turn when '
#          'one of them is struck by a mysterious affliction. Now, in a foreign '
#          'land, they race to uncover the source before it consumes him '
#          'completely.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjEzOTczNzA0NF5BMl5BanBnXkFtZTgwMTgwNTYyMTE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 1, 27, 0, 0),
#  'runtime': 85,
#  'title': 'Afflicted',
#  'tomatoes': {'boxOffice': '$0.1M',
#               'consensus': "It isn't without its share of clichès, but "
#                            "Afflicted proves there's still life in the "
#                            'found-footage horror genre.',
#               'critic': {'meter': 79, 'numReviews': 24, 'rating': 6.6},
#               'dvd': datetime.datetime(2014, 7, 1, 0, 0),
#               'fresh': 19,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 17, 55, 22),
#               'production': 'CBS Films',
#               'rotten': 5,
#               'viewer': {'meter': 57, 'numReviews': 9759, 'rating': 3.3},
#               'website': 'http://afflicted-movie.com/'},
#  'type': 'movie',
#  'writers': ['Derek Lee (screenplay)', 'Clif Prowse (screenplay)'],
#  'year': 2013}
# {'_id': ObjectId('573a13d9f29313caabda92c0'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Marlon Wayans', 'Marlene Forte', 'Essence Atkins', 'David Koechner'],
#  'countries': ['USA'],
#  'directors': ['Michael Tiddes'],
#  'fullplot': 'In October 2012 a video footage is found at the home of Malcolm '
#              'Johnson and the recordings are still unexplained. Past this '
#              'prologue a story in flashback form unfolds. During the summer of '
#              '2012, Malcolm and Kisha move in together and start a happy life. '
#              'One night Kisha notices a few unexplained phenomena that '
#              'convince her their house is haunted by ghosts. To allay her '
#              'fears Malcom hires a camera crew to film inside the house day '
#              'and night. A few nights later Malcom and Keisha have sex on '
#              "camera, despite Keisha's protests at being filmed. Upon "
#              'reviewing the sex tape the next day, Malcom and Keisha notice a '
#              'few paranormal phenomena caught on tape. Malcom wants to sell '
#              'the house but the housing market is slow. Therefore, Malcom '
#              'decides to hire a psychic to come to the house and investigate. '
#              'After Kisha confesses to making a deal with the devil for a pair '
#              "of shoes things start to make sense but it doesn't solve the "
#              'problems caused by the paranormal phenomena.',
#  'genres': ['Comedy', 'Horror'],
#  'imdb': {'id': 2243537, 'rating': 5.1, 'votes': 31442},
#  'languages': ['English', 'Spanish'],
#  'lastupdated': '2015-08-23 00:29:23.780000000',
#  'metacritic': 20,
#  'num_mflix_comments': 0,
#  'plot': 'Malcolm and Kisha move into their dream home, but soon learn a demon '
#          'also resides there. When Kisha becomes possessed, Malcolm - '
#          'determined to keep his sex life on track - turns to a priest, a '
#          'psychic, and a team of ghost-busters for help.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTM1ODgyOTI0NF5BMl5BanBnXkFtZTcwODgyMDY3OA@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2013, 1, 11, 0, 0),
#  'runtime': 86,
#  'title': 'A Haunted House',
#  'tomatoes': {'boxOffice': '$40.0M',
#               'critic': {'meter': 10, 'numReviews': 51, 'rating': 2.6},
#               'dvd': datetime.datetime(2013, 4, 23, 0, 0),
#               'fresh': 5,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 17, 6, 10),
#               'production': 'Open Road Films',
#               'rotten': 46,
#               'viewer': {'meter': 51, 'numReviews': 91403, 'rating': 3.2},
#               'website': 'http://www.facebook.com/AHauntedHouse'},
#  'type': 'movie',
#  'writers': ['Marlon Wayans', 'Rick Alvarez'],
#  'year': 2013}
# {'_id': ObjectId('573a13dbf29313caabdaf480'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Dylan Postl',
#           'Stephanie Bennett',
#           'Andrew Dunbar',
#           'Melissa Roxburgh'],
#  'countries': ['USA'],
#  'directors': ['Zach Lipovsky'],
#  'fullplot': 'Backpacking through the lush Irish countryside, two unsuspecting '
#              "young couples discover a town's chilling secret. Ben (Dunbar), "
#              'Sophie (Bennet), David (Fletcher) and Jeni (Roxburgh) quickly '
#              'discover the idyllic land is not what it appears to be when the '
# ...
#              'him. Kicked out of his big city apartment, Raymond returns home '
#              'to his overbearing mother, ex-jock father, and beer-bellied '
#              'classmates. But when a vengeful ghost terrorizes the small town, '
#              'the city-boy recruits Becca, a badass local bartender, to solve '
#              "the mystery of the spirit threatening everyone's lives.",
#  'genres': ['Comedy', 'Horror', 'Romance'],
#  'imdb': {'id': 3279176, 'rating': 5.6, 'votes': 1260},
#  'languages': ['English'],
#  'lastupdated': '2015-08-30 00:05:07.023000000',
#  'metacritic': 49,
#  'num_mflix_comments': 2,
#  'plot': "Raymond has a prestigious MBA, but he can't find work. He can "
#          'channel the paranormal, but chatting with a cute girl mystifies him. '
#          'Kicked out of his big city apartment, Raymond returns home...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTk5NzYyNDYwOV5BMl5BanBnXkFtZTgwNzk5NDQ0NTE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 1, 30, 0, 0),
#  'runtime': 90,
#  'title': 'Suburban Gothic',
#  'type': 'movie',
#  'writers': ['Richard Bates Jr.', 'Mark Bruner'],
#  'year': 2014}
# {'_id': ObjectId('573a13e9f29313caabdcd65e'),
#  'awards': {'nominations': 6, 'text': '6 nominations.', 'wins': 0},
#  'cast': ['Annabelle Wallis', 'Ward Horton', 'Tony Amendola', 'Alfre Woodard'],
#  'countries': ['USA'],
#  'directors': ['John R. Leonetti'],
#  'fullplot': 'John Form has found the perfect gift for his expectant wife, Mia '
#              '- a beautiful, rare vintage doll in a pure white wedding dress. '
#              "But Mia's delight with Annabelle doesn't last long. On one "
#              'horrific night, their home is invaded by members of a satanic '
#              'cult, who violently attack the couple. Spilled blood and terror '
#              'are not all they leave behind. The cultists have conjured an '
#              'entity so malevolent that nothing they did will compare to the '
#              'sinister conduit to the damned that is now... Annabelle..',
#  'genres': ['Horror', 'Mystery'],
#  'imdb': {'id': 3322940, 'rating': 5.4, 'votes': 65489},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:06:03.123000000',
#  'metacritic': 37,
#  'num_mflix_comments': 0,
#  'plot': 'A couple begins to experience terrifying supernatural occurrences '
#          'involving a vintage doll shortly after their home is invaded by '
#          'satanic cultists.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BOTQwZmQyYzEtODk5ZC00OTY3LWExMjAtYzRjNWFhNGM3MzBlXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2014, 10, 3, 0, 0),
#  'runtime': 99,
#  'title': 'Annabelle',
#  'type': 'movie',
#  'writers': ['Gary Dauberman'],
#  'year': 2014}
# {'_id': ObjectId('573a13f4f29313caabde0bfd'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Rory Culkin', 'Leticia Jimenez', 'Jack Kesy', 'Timothy T. McKinney'],
#  'countries': ['USA'],
#  'directors': ['Adam Schindler'],
#  'fullplot': 'Anna suffers from agoraphobia so crippling that when a trio of '
#              'criminals break into her house, she cannot bring herself to '
#              "flee. But what the intruders don't realize is that agoraphobia "
#              'is not her only psychosis.',
#  'genres': ['Drama', 'Horror', 'Thriller'],
#  'imdb': {'id': 4009278, 'rating': 7.1, 'votes': 79},
#  'languages': ['English'],
#  'lastupdated': '2015-09-17 02:00:44.673000000',
#  'num_mflix_comments': 0,
#  'plot': 'Anna suffers from agoraphobia so crippling that when a trio of '
#          'criminals break into her house, she cannot bring herself to flee. '
#          "But what the intruders don't realize is that agoraphobia is not her "
#          'only psychosis.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY5MzE0MjUwNV5BMl5BanBnXkFtZTgwNjQxNzM2NzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2016, 2, 19, 0, 0),
#  'runtime': 90,
#  'title': 'Shut In',
#  'type': 'movie',
#  'writers': ['T.J. Cimfel', 'David White'],
#  'year': 2015}
# {'_id': ObjectId('573a13f4f29313caabde254c'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Carrie-Anne Moss', 'Xavier Samuel', 'Danny Huston', 'Tony Todd'],
#  'countries': ['USA', 'Germany'],
#  'directors': ['Bernard Rose'],
#  'fullplot': 'A married couple of scientists create a modern-day monster.',
#  'genres': ['Horror', 'Thriller'],
#  'imdb': {'id': 4086032, 'rating': 6.2, 'votes': 106},
#  'languages': ['English'],
#  'lastupdated': '2015-09-04 00:11:27.633000000',
#  'num_mflix_comments': 0,
#  'plot': 'A married couple of scientists create a modern-day monster.',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 9, 25, 0, 0),
#  'runtime': 89,
#  'title': 'Frankenstein',
#  'type': 'movie',
#  'writers': ['Bernard Rose'],
#  'year': 2015}
# {'_id': ObjectId('573a13f5f29313caabde3411'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Katie Savoy', 'Chris Riedell', 'Lincoln Hoppe', 'Chris Dinh'],
#  'countries': ['USA'],
#  'directors': ['Viet Nguyen'],
#  'fullplot': 'A couple of master thieves find themselves trapped within a '
#              "house they intended to rob, only to discover they've "
#              'inadvertently wandered into the lair of a deranged serial '
#              'killer.',
#  'genres': ['Comedy', 'Horror', 'Thriller'],
#  'imdb': {'id': 4149732, 'rating': 6.4, 'votes': 19},
#  'languages': ['English'],
#  'lastupdated': '2015-09-14 08:37:46.063000000',
#  'num_mflix_comments': 0,
#  'plot': 'A couple of master thieves find themselves trapped within a house '
#          "they intended to rob, only to discover they've inadvertently "
#          'wandered into the lair of a deranged serial killer.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTkxNDg4OTAxNl5BMl5BanBnXkFtZTgwNDI1MjAwNjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 6, 11, 0, 0),
#  'runtime': 80,
#  'title': 'Crush the Skull',
#  'type': 'movie',
#  'writers': ['Chris Dinh', 'Viet Nguyen'],
#  'year': 2015}
# {'_id': ObjectId('573a13f3f29313caabde067d'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Polina Davydova', 'Lyubov Ignatushko', 'Evgeniy Gagarin'],
#  'countries': ['Germany', 'Russia'],
#  'directors': ['Pavel Khvaleev'],
#  'fullplot': 'A small European town, where sisters Ayia and Mirra live, gets '
#              'struck down by an unknown disease which takes many lives. '
#              "Following their mother's death, the younger sister falls ill. "
#              'Having realized that conventional medicine is useless in the '
#              "face of the sister's disease, Ayia seeks help from Father "
#              'Herman, a parish priest and a close family friend. In his house '
#              'she finds books that are very far from the conventional '
#              "religion. She gets to know that only penetration into Mirra's "
#              'sick subconscious mind and discovery of the true cause of her '
#              'disease will give her a chance to save her sister. Ayia is ready '
#              'to go through this terrifying ritual, dive into the depths of '
#              'the subconscious mind, and face the demons residing there.',
#  'genres': ['Drama', 'Horror', 'Thriller'],
#  'imdb': {'id': 3993732, 'rating': 6.7, 'votes': 249},
#  'languages': ['Russian'],
#  'lastupdated': '2015-08-20 00:58:42.127000000',
#  'num_mflix_comments': 0,
#  'plot': 'A small European town, where sisters Ayia and Mirra live, gets '
#          'struck down by an unknown disease which takes many lives. Following '
#          "their mother's death, the younger sister falls ill. Having...",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjM4NzE0MDAzN15BMl5BanBnXkFtZTgwMjk0MzYwNzE@._V1_SY1000_SX677_AL_.jpg',
#  'runtime': 80,
#  'title': 'III',
#  'type': 'movie',
#  'writers': ['Aleksandra Khvaleeva (story)',
#              'Aleksandra Khvaleeva',
#              'Aleksandra Khvaleeva',
#              'Oleg Mustafin (story)',
#              'Evgeniya Mustafina (story)'],
#  'year': 2015}
# {'_id': ObjectId('573a13f4f29313caabde1834'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Kristian Fjord',
#           'Jacob Wagner Guldager',
#           'Casper Sloth',
#           'Signe Mathilde Sèrensen'],
#  'countries': ['Denmark', 'Sweden'],
#  'directors': ['Anders Johannes Bukh'],
#  'fullplot': 'November 18th 2011 a small Danish film crew disappeared in the '
#              'woods of northern Sweden without a trace. One year later, their '
#              'footage was leaked by a hacker group now known as Pandoras. This '
#              "is the crew's unsettling and disturbing footage.",
#  'genres': ['Horror', 'Mystery', 'Sci-Fi'],
#  'imdb': {'id': 4047752, 'rating': 6.9, 'votes': 77},
#  'languages': ['Danish'],
#  'lastupdated': '2015-09-06 00:16:10.650000000',
#  'num_mflix_comments': 0,
#  'plot': 'Encounters - The woods have secrets.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMzQxODQ2OTg3MV5BMl5BanBnXkFtZTgwMDE3MDMxMzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 10, 30, 0, 0),
#  'runtime': 95,
#  'title': 'Encounters',
#  'type': 'movie',
#  'writers': ['Anders Johannes Bukh', 'Anders Johannes Bukh'],
#  'year': 2014}
# {'_id': ObjectId('573a13f1f29313caabddbdbe'),
#  'awards': {'nominations': 3, 'text': '3 nominations.', 'wins': 0},
#  'cast': ['Chutavuth Pattarakampol',
#           'Supassra Thanachat',
#           'Thanapob Leeratanakajorn',
#           'Violette Wautier'],
#  'countries': ['Thailand'],
#  'directors': ['Sophon Sakdaphisit'],
#  'fullplot': "After falling pregnant to Perth, her boyfriend's best friend, "
#              'Ice commits suicide. She returns to haunt Perth while Tan seeks '
#              'out the person who made her kill herself for his own revenge.',
#  'genres': ['Drama', 'Horror'],
#  'imdb': {'id': 3788392, 'rating': 6.0, 'votes': 237},
#  'languages': ['Thai'],
#  'lastupdated': '2015-08-02 00:34:26.467000000',
#  'num_mflix_comments': 0,
#  'plot': "After falling pregnant to Perth, her boyfriend's best friend, Ice "
#          'commits suicide. She returns to haunt Perth while Tan seeks out the '
#          'person who made her kill herself for his own revenge.',
#  'released': datetime.datetime(2014, 8, 7, 0, 0),
#  'title': 'The Swimmers',
#  'type': 'movie',
#  'year': 2014}
# {'_id': ObjectId('573a13f3f29313caabdde5a7'),
#  'awards': {'nominations': 2, 'text': '2 wins & 2 nominations.', 'wins': 2},
#  'cast': ['Hye-Lin Han', 'Haneul Kang', 'So-eun Kim', 'Doo-Sik Park'],
#  'countries': ['South Korea'],
#  'directors': ['In-chun Oh'],
#  'fullplot': 'In-Su, a high school student, can see ghosts. After being '
#              'plagued by them everywhere he goes and harassed by his '
#              'classmates because of it, he returns to his hometown to live '
#              'with his uncle and to finally put to rest the past. No sooner '
#              'had he arrived when he sees his first ghost there, a pretty '
#              "girl. But just like before, it's not just the ghosts that affect "
#              'his life - the school bullies in the high school in his hometown '
#              'are still a problem. Then one day, the bullies start being '
#              'attacked by a vengeful ghost wearing a bloody mask. And In-Su '
#              'starts to think that his new friend, the pretty ghost, may have '
#              'something to do with it.',
#  'genres': ['Comedy', 'Horror', 'Romance'],
#  'imdb': {'id': 3892620, 'rating': 6.1, 'votes': 311},
#  'languages': ['Korean'],
#  'lastupdated': '2015-09-14 17:29:04.413000000',
#  'num_mflix_comments': 1,
#  'plot': 'A teenager, with the ability to see ghosts, returns to his hometown '
#          'to face his demons.',
#  'released': datetime.datetime(2014, 7, 2, 0, 0),
#  'runtime': 90,
#  'title': 'Sonyeogoedam',
#  'type': 'movie',
#  'writers': ['Jong-ho Lee'],
#  'year': 2014}
# {'_id': ObjectId('573a13f4f29313caabde1d9a'),
#  'awards': {'nominations': 1, 'text': '3 wins & 1 nomination.', 'wins': 3},
#  'cast': ['Imogen Poots', 'Patrick Stewart', 'Alia Shawkat', 'Anton Yelchin'],
#  'countries': ['USA'],
#  'directors': ['Jeremy Saulnier'],
#  'fullplot': 'A band straying into a secluded part of the Pacific Northwest, '
#              'stumbles on to a horrific act of violence. Because they are the '
#              'only witnesses, they become the targets of a terrifying gang of '
#              'white power skinheads who want to make sure all the evidence is '
#              'eliminated.',
#  'genres': ['Horror', 'Thriller'],
#  'imdb': {'id': 4062536, 'rating': 7.4, 'votes': 124},
#  'languages': ['English'],
#  'lastupdated': '2015-09-06 00:23:02.447000000',
#  'metacritic': 78,
#  'num_mflix_comments': 1,
#  'plot': 'A young punk rock band find themselves trapped in a secluded venue '
#          'after stumbling upon a horrific act of violence.',
#  'released': datetime.datetime(2015, 5, 17, 0, 0),
#  'runtime': 94,
#  'title': 'Green Room',
#  'type': 'movie',
#  'writers': ['Jeremy Saulnier'],
#  'year': 2015}
# {'_id': ObjectId('573a13f3f29313caabddf5a5'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Francisco Barreiro',
#           'Daniela Soto Vell',
#           'Jorge Molina',
#           'Milena Pezzi'],
#  'countries': ['Mexico', 'USA'],
#  'directors': ['Adrièn Garcèa Bogliano'],
#  'genres': ['Comedy', 'Horror'],
#  'imdb': {'id': 3951730, 'rating': 6.2, 'votes': 41},
#  'languages': ['Spanish'],
#  'lastupdated': '2015-08-14 00:13:02.740000000',
#  'num_mflix_comments': 0,
#  'released': datetime.datetime(2015, 4, 17, 0, 0),
#  'runtime': 91,
#  'title': 'Scherzo Diabolico',
#  'type': 'movie',
#  'writers': ['Adrièn Garcèa Bogliano'],
#  'year': 2015}
# {'_id': ObjectId('573a13f9f29313caabde9c7b'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Yael Grobglas',
#           'Yon Tumarkin',
#           'Danielle Jadelyn',
#           'Dibi Ben-Yosef'],
#  'countries': ['Israel'],
#  'directors': ['Doron Paz', 'Yoav Paz'],
#  'fullplot': 'When a couple of American young adults fly to Israel to visit '
#              'the city of Jerusalem, a biblical nightmare falls upon the city',
#  'genres': ['Horror'],
#  'imdb': {'id': 4552524, 'rating': 6.3, 'votes': 34},
#  'languages': ['English'],
#  'lastupdated': '2015-08-14 00:11:46.537000000',
#  'num_mflix_comments': 0,
#  'plot': 'When a couple of American young adults fly to Israel to visit the '
#          'city of Jerusalem, a biblical nightmare falls upon the city',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTc2MjU2ODY3M15BMl5BanBnXkFtZTgwMTg5OTc3NTE@._V1_SY1000_SX677_AL_.jpg',
#  'runtime': 87,
#  'title': 'Jeruzalem',
#  'type': 'movie',
#  'writers': ['Doron Paz (paz brothers)', 'Yoav Paz (paz brothers)'],
#  'year': 2015}
# {'_id': ObjectId('573a13f6f29313caabde4e7e'),
#  'awards': {'nominations': 2, 'text': '1 win & 2 nominations.', 'wins': 1},
#  'cast': ['Anya Taylor-Joy', 'Ralph Ineson', 'Kate Dickie', 'Harvey Scrimshaw'],
#  'countries': ['Canada', 'USA'],
#  'directors': ['Robert Eggers'],
#  'fullplot': 'New England, 1630: William and Katherine lead a devout Christian '
#              'life, homesteading on the edge of an impassible wilderness, with '
#              'five children. When their newborn son mysteriously vanishes and '
#              "their crops fail, the family begins to turn on one another. 'The "
#              "Witch' is a chilling portrait of a family unraveling within "
#              'their own fears and anxieties, leaving them prey for an '
#              'inescapable evil.',
#  'genres': ['Horror'],
#  'imdb': {'id': 4263482, 'rating': 7.5, 'votes': 612},
#  'languages': ['English'],
#  'lastupdated': '2015-09-03 00:41:47.413000000',
#  'metacritic': 90,
#  'num_mflix_comments': 1,
#  'plot': 'The age-old concepts of witchcraft, black magic and possession are '
#          "innovatively brought together to tell the story of one family's "
#          'frightful unraveling.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTUyNzkwMzAxOF5BMl5BanBnXkFtZTgwMzc1OTk1NjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'runtime': 90,
#  'title': 'The Witch',
#  'type': 'movie',
#  'writers': ['Robert Eggers'],
#  'year': 2015}

# %% [markdown]
# #5
# 1. Ensure the title field is indexed for serch in MongoDB and write a query to search for movies that contain the word "love" in their titles.

# %%
try:
    collection.drop_indexes()
    collection.create_index([('title', 'text')])
except:
    collection.create_index([('title', 'text')])
finally:
  love_movies = collection.find({'$text': {'$search': 'love'}}).limit(5)

  for movie in love_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13a6f29313caabd19168'),
#  'awards': {'nominations': 2, 'text': '2 nominations.', 'wins': 0},
#  'cast': ['Audrey Tautou',
#           'Samuel Le Bihan',
#           'Isabelle Carrè',
#           'Sophie Guillemin'],
#  'countries': ['France'],
#  'directors': ['Laetitia Colombani'],
#  'fullplot': 'Angelique, a young student, is in love with a married doctor. We '
#              'see her attempts to make him leave his pregnant wife, but he '
#              'does not appear for meetings or finally the booked journey to '
#              'Florence. Then the movie is turned back to the beginning, and '
#              'the view changes: We are now following the view of the doctor '
#              'instead of Angeliques. And things look quite different now...',
#  'genres': ['Romance', 'Thriller'],
#  'imdb': {'id': 291579, 'rating': 7.3, 'votes': 15360},
#  'languages': ['French'],
#  'lastupdated': '2015-09-10 17:15:26.557000000',
#  'metacritic': 63,
#  'num_mflix_comments': 0,
#  'plot': 'A young woman who is in love with a married doctor becomes dangerous '
#          'when her attempts to persuade him to leave his wife are '
#          'unsuccessful. However, when things are seen from his point of view, '
#          'the real situation becomes clear.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjE0NzcwMjM4Ml5BMl5BanBnXkFtZTcwMjgyMjEyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2002, 3, 27, 0, 0),
#  'runtime': 92,
#  'title': 'He Loves Me... He Loves Me Not',
#  'tomatoes': {'boxOffice': '$0.4M',
#               'consensus': "This romantic thriller puts Tautou's sweetheart "
#                            'Amelie image to good use.',
#               'critic': {'meter': 73, 'numReviews': 71, 'rating': 6.8},
#               'dvd': datetime.datetime(2003, 8, 12, 0, 0),
#               'fresh': 52,
#               'lastUpdated': datetime.datetime(2015, 7, 23, 18, 42, 57),
#               'production': 'Samuel Goldwyn Company',
#               'rotten': 19,
#               'viewer': {'meter': 85, 'numReviews': 22933, 'rating': 3.8},
#               'website': 'http://www.helovesmethemovie.com'},
#  'type': 'movie',
#  'writers': ['Laetitia Colombani', 'Caroline Thivel (collaborating writer)'],
#  'year': 2002}
# {'_id': ObjectId('573a139af29313caabcf1a82'),
#  'awards': {'nominations': 1, 'text': '2 wins & 1 nomination.', 'wins': 2},
#  'cast': ['Roman Klosowski', 'Iva Janzurovè', 'Milan Jelic', 'Milada Jezkovè'],
#  'countries': ['Czechoslovakia'],
#  'directors': ['Dusan Hanèk'],
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 123920, 'rating': 7.2, 'votes': 91},
#  'languages': ['Slovak'],
#  'lastupdated': '2015-03-15 00:52:30.840000000',
#  'num_mflix_comments': 0,
#  'released': datetime.datetime(1989, 2, 15, 0, 0),
#  'runtime': 95,
#  'title': 'I Love, You Love',
#  'tomatoes': {'critic': {'meter': 60, 'numReviews': 5, 'rating': 5.8},
#               'dvd': datetime.datetime(2000, 7, 11, 0, 0),
#               'fresh': 3,
#               'lastUpdated': datetime.datetime(2015, 9, 11, 17, 56, 34),
#               'production': 'Strand',
#               'rotten': 2,
#               'viewer': {'meter': 61, 'numReviews': 888, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['Dusan Dusek', 'Dusan Hanèk'],
#  'year': 1989}
# {'_id': ObjectId('573a13bcf29313caabd56e29'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Mark Strong'],
#  'countries': ['UK'],
#  'directors': ['Nick Holt'],
#  'genres': ['Documentary', 'Romance'],
#  'imdb': {'id': 968743, 'rating': 7.2, 'votes': 170},
#  'languages': ['English'],
#  'lastupdated': '2015-08-06 00:20:05.913000000',
#  'num_mflix_comments': 1,
#  'released': datetime.datetime(2007, 1, 17, 0, 0),
#  'runtime': 50,
#  'title': 'Love Me, Love My Doll',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 20, 18, 57, 39),
#               'viewer': {'numReviews': 671, 'rating': 4.8}},
#  'type': 'movie',
#  'year': 2007}
# {'_id': ObjectId('573a13a0f29313caabd04510'),
#  'awards': {'nominations': 5, 'text': '6 wins & 5 nominations.', 'wins': 6},
#  'cast': ['Sabine Timoteo',
#           'Florian Stetter',
#           'Michael Schech',
#           'Dierk Prawdzik'],
#  'countries': ['Germany', 'Switzerland', 'France'],
#  'directors': ['Philip Grèning'],
#  'fullplot': 'David, a recently fired scrapyard worker and Marie, a '
#              "prostitute, both about 20 years old, meet on New Year's Eve in "
#              "Berlin and decide to run away together. As David's arm is "
#              'plastered from an accident Marie continues to prostitute herself '
#              'to finance their restless journey through the Ruhr area. Their '
#              'love and their will to survive guide them though all problems.',
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 203297, 'rating': 4.0, 'votes': 469},
#  'languages': ['German'],
#  'lastupdated': '2015-07-28 00:13:00.043000000',
#  'num_mflix_comments': 0,
#  'plot': 'David, a recently fired scrapyard worker and Marie, a prostitute, '
#          "both about 20 years old, meet on New Year's Eve in Berlin and decide "
#          "to run away together. As David's arm is plastered from...",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTg0ODU5MTIxNF5BMl5BanBnXkFtZTcwNjk0NDQyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2002, 11, 21, 0, 0),
#  'runtime': 137,
#  'title': 'Love, Money, Love',
#  'tomatoes': {'dvd': datetime.datetime(2000, 1, 11, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 11, 17, 56, 4),
#               'production': 'Full Moon',
#               'viewer': {'meter': 48, 'numReviews': 2131, 'rating': 2.9}},
#  'type': 'movie',
#  'writers': ['Michael Busch', 'Philip Grèning'],
#  'year': 2000}
# {'_id': ObjectId('573a13f1f29313caabddb616'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Aomi Muyock', 'Karl Glusman', 'Klara Kristin', 'Juan Saavedra'],
#  'countries': ['France', 'Belgium'],
#  'directors': ['Gaspar Noè'],
#  'fullplot': "A sexual melodrama about a boy and a girl and another girl. It's "
#              'a love story, which celebrates sex in a joyous way.',
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 3774694, 'rating': 6.3, 'votes': 660},
#  'languages': ['English'],
#  'lastupdated': '2015-09-05 00:41:35.807000000',
#  'metacritic': 54,
#  'num_mflix_comments': 1,
#  'plot': "A sexual melodrama about a boy and a girl and another girl. It's a "
#          'love story, which celebrates sex in a joyous way.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQzNDUwODk5NF5BMl5BanBnXkFtZTgwNzA0MDQ2NTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 11, 6, 0, 0),
#  'runtime': 134,
#  'title': 'Love',
#  'type': 'movie',
#  'writers': ['Gaspar Noè'],
#  'year': 2015}

# %% [markdown]
# 2. Write a text search query to find movies where the word "war" appears in the title or plot, sorted by IMDb rating (Return only the top 5 results).

# %%
collection.drop_indexes()
collection.create_index([('title', 'text'), ('plot', 'text')])
war_movies = collection.find({'$text': {'$search': 'war'}}).sort('imdb.rating', -1).limit(5)

for movie in war_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13eef29313caabdd676a'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Joe Berry', 'Uncle Bob', 'Sam Doungaphay', 'Sokmakara Hang'],
#  'countries': ['USA'],
#  'directors': ['Sara Dosa'],
#  'fullplot': 'In search of the lucrative matsutake mushroom, two former '
#              'soldiers discover the means to gradually heal their wounds of '
#              "war. Roger, a self-described 'fall-down drunk' and sniper in "
#              'Vietnam, and Kouy, a Cambodian refugee who fought the Khmer '
#              'Rouge, bonded in the bustling tent-city known as Mushroom Camp, '
#              'which pops up each autumn in the Oregon woods. Their friendship '
#              'became an adoptive family; according to a Cambodian custom, if '
#              'you lose your family like Kouy, you must rebuilt it anew. Now, '
#              "however, this new family could be lost. Roger's health is "
#              'declining and trauma flashbacks rack his mind; Kouy gently aids '
#              'his family before the snow falls and the hunting season ends, '
#              'signaling his time to leave.',
#  'genres': ['Documentary', 'Family', 'War'],
#  'imdb': {'id': 3593932, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2014-09-20 04:04:23.547000000',
#  'num_mflix_comments': 1,
#  'plot': 'In search of the lucrative matsutake mushroom, two former soldiers '
#          'discover the means to gradually heal their wounds of war. Roger, a '
#          "self-described 'fall-down drunk' and sniper in Vietnam,...",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY2NDYzNDcyOF5BMl5BanBnXkFtZTgwNTAxNjkyMjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 4, 25, 0, 0),
#  'runtime': 78,
#  'title': 'The Last Season',
#  'type': 'movie',
#  'year': 2014}
# {'_id': ObjectId('573a13f2f29313caabddcf5f'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Pilou Asbèk', 'Tuva Novotny', 'Sèren Malling', 'Dar Salim'],
#  'countries': ['Denmark'],
#  'directors': ['Tobias Lindholm'],
#  'fullplot': 'Company commander Claus M. Pedersen (Pilou Asbèk) and his men '
#              'are stationed in an Afghan province. Meanwhile back in Denmark '
#              "Claus' wife Maria (Tuva Novotny) is trying to hold everyday life "
#              'together with a husband at war and three children missing their '
#              'father. During a routine mission, the soldiers are caught in '
#              'heavy crossfire and in order to save his men, Claus makes a '
#              'decision that has grave consequences for him - and his family '
#              'back home.',
#  'genres': ['Drama', 'War'],
#  'imdb': {'id': 3830162, 'rating': '', 'votes': ''},
#  'languages': ['Danish'],
#  'lastupdated': '2015-09-05 00:28:23.783000000',
#  'num_mflix_comments': 0,
#  'plot': 'Company commander Claus M. Pedersen (Pilou Asbèk) and his men are '
#          "stationed in an Afghan province. Meanwhile back in Denmark Claus' "
#          'wife Maria (Tuva Novotny) is trying to hold everyday life...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjA1ODY3NjQzNV5BMl5BanBnXkFtZTgwNjEzNTUxNzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 9, 10, 0, 0),
#  'title': 'A War',
#  'type': 'movie',
#  'writers': ['Tobias Lindholm'],
#  'year': 2015}
# {'_id': ObjectId('573a13e2f29313caabdbe708'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Robert Pattinson',
#           'Liam Cunningham',
#           'Stacy Martin',
#           'Bèrènice Bejo'],
#  'countries': ['France'],
#  'directors': ['Brady Corbet'],
#  'fullplot': 'This chilling fable about the rise of fascism in the 20th '
#              'Century tells the story of a young American boy living in France '
#              'in 1918 whose father is working for the US government on the '
#              'creation of the Treaty of Versailles. What he witnesses helps to '
#              'mould his beliefs - and we witness the birth of a terrifying '
#              'ego. Loosely inspired by the early childhood experiences of many '
#              'of the great dictators of the 20th Century and infused with the '
#              'same sense of dread as The Others and The Omen, The Childhood of '
#              'a Leader is an ominous portrait of emerging evil.',
#  'genres': ['Drama', 'Horror', 'Mystery'],
#  'imdb': {'id': 2815902, 'rating': '', 'votes': ''},
#  'lastupdated': '2015-08-31 00:00:22.140000000',
#  'num_mflix_comments': 1,
#  'plot': 'A look at the childhood life of a a post-World War I leader.',
#  'title': 'The Childhood of a Leader',
#  'tomatoes': {'lastUpdated': datetime.datetime(2014, 11, 16, 2, 47, 43),
#               'viewer': {'numReviews': 0, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Brady Corbet (screenplay)', 'Mona Fastvold'],
#  'year': 2015}
# {'_id': ObjectId('573a1398f29313caabcebc0b'),
#  'awards': {'nominations': 3,
#             'text': 'Won 2 Primetime Emmys. Another 8 wins & 3 nominations.',
#             'wins': 10},
#  'cast': ['Sam Waterston', 'Julie Harris', 'Jason Robards', 'Morgan Freeman'],
#  'countries': ['USA'],
#  'fullplot': 'This highly acclaimed mini series traces the course of the U.S. '
#              'Civil War from the abolitionist movement through all the major '
#              'battles to the death of President Lincoln and the beginnings of '
#              'Reconstruction. The story is mostly told in the words of the '
#              'participants themselves, through their diaries, letters, and '
#              'Visuals are usually still photographs and illustrations of the '
#              'time, and the soundtrack is likewise made up of war-era tunes '
#              'played on period instruments. Several modern-day historians '
#              "offer periodic comment and insight on the war's causes and "
#              'events.',
#  'genres': ['Documentary', 'History', 'War'],
#  'imdb': {'id': 98769, 'rating': 9.4, 'votes': 4625},
#  'languages': ['English'],
#  'lastupdated': '2015-09-01 00:13:15.693000000',
#  'num_mflix_comments': 1,
#  'plot': 'A comprehensive survey of the American Civil War.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZDc1NzI2MGEtZDA2Yy00ZWExLTgwYmItNjU3N2QyYmM0MzYwXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1990, 9, 23, 0, 0),
#  'runtime': 680,
#  'title': 'The Civil War',
#  'tomatoes': {'dvd': datetime.datetime(2006, 1, 10, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 25, 19, 21, 52),
#               'production': 'Pet Fly Productions',
#               'viewer': {'meter': 56, 'numReviews': 466, 'rating': 3.2}},
#  'type': 'series',
#  'year': 1990}
# {'_id': ObjectId('573a13a3f29313caabd0e77b'),
#  'awards': {'nominations': 3,
#             'text': 'Won 2 Primetime Emmys. Another 8 wins & 3 nominations.',
#             'wins': 10},
#  'cast': ['Sam Waterston', 'Julie Harris', 'Jason Robards', 'Morgan Freeman'],
#  'countries': ['USA'],
#  'fullplot': 'This highly acclaimed mini series traces the course of the U.S. '
#              'Civil War from the abolitionist movement through all the major '
#              'battles to the death of President Lincoln and the beginnings of '
#              'Reconstruction. The story is mostly told in the words of the '
#              'participants themselves, through their diaries, letters, and '
#              'Visuals are usually still photographs and illustrations of the '
#              'time, and the soundtrack is likewise made up of war-era tunes '
#              'played on period instruments. Several modern-day historians '
#              "offer periodic comment and insight on the war's causes and "
#              'events.',
#  'genres': ['Documentary', 'History', 'War'],
#  'imdb': {'id': 98769, 'rating': 9.4, 'votes': 4624},
#  'languages': ['English'],
#  'lastupdated': '2015-08-30 22:52:05.467000000',
#  'num_mflix_comments': 0,
#  'plot': 'A comprehensive survey of the American Civil War.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZDc1NzI2MGEtZDA2Yy00ZWExLTgwYmItNjU3N2QyYmM0MzYwXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1990, 9, 23, 0, 0),
#  'runtime': 680,
#  'title': 'The Civil War',
#  'type': 'series',
#  'year': 1990}
